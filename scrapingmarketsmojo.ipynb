# %% [markdown]
# <a href="https://colab.research.google.com/github/yash-1708/Stock-Analyst-Rating/blob/master/scrapingmarketsmojo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
driver = webdriver.Chrome("chromedriver.exe")
broker=[] #List to store name of the broker
company_name=[] #List to store company names 
current_price=[] #List to store rating of the product
predict_date=[]
recomended_buying=[]
target_price=[]
driver.get("https://www.marketsmojo.com/recommendation/")
content = driver.page_source
soup = BeautifulSoup(content,'html.parser')
Alldata=soup.select_one("div.righttexcontent2 div.right-table01 div.scr-result2")

# %%
# for row in Alldata.findAll('div',class_='middle-colum02'):
for row in Alldata.findAll('div',attrs={'class':'middle-colum02'}):
    broker.append(row.select("div.colum2-midd01 div.row div.margin-text ul.reco-price li div.text-top0 a.broker-link")[0].get_text())
    company_name.append(row.select("div.colum2-midd02 div.row div.margin-text ul.reco-price li div.text-top0 a.broker-link")[0].get_text().replace('\t','').replace('\n',''))
    current_price.append(row.select("div.colum2-midd03 div.row div.margin-text ul.reco-price li div.text-top0")[0].get_text())
    recomended_buying.append(row.select("div.colum2-midd04 div.row div.margin-text ul.reco-price div.text-top0")[0].get_text())
    target_price.append(row.select("div.colum2-midd05 div.row div.margin-text ul.reco-price li div.text-top0")[0].get_text())
    temp_data=row.select("div.colum2-midd04 div.row div.margin-text ul.reco-price div.colum-text-color-bott")
    temp_data=str(temp_data).split('on ')[1]
    temp_data=temp_data.split('<br/')[0]
    predict_date.append(temp_data)
    #predict_date.append(row.select("div.colum2-midd04 div.row div.margin-text ul.reco-price div.colum-text-color-bott"))

# %% [markdown]
# Test Cell

# %%
temp_data      #test
# Out:
# '30 Jul 19'

# %% [markdown]
# Classifying into different dataframes

# %%
df1 = pd.DataFrame({'broker':broker})  
df2 = pd.DataFrame({'company_name':company_name})
df3 = pd.DataFrame({'current_price':current_price})
df4 = pd.DataFrame({'recomended_buing':recomended_buying})
df5=pd.DataFrame({'target_price':target_price})
df6=pd.DataFrame({'predict_date':predict_date})
#dfALL = pd.DataFrame(broker,company_name,current_price,recomended_buying,target_price)

# %% [markdown]
# Cleaning Data

# %%
#splitting operation
rb=df4['recomended_buing'].str.split('Rs.').str[1] 
cp=df3['current_price'].str.split('Rs.').str[1]
tp=df5['target_price'].str.split('Rs.').str[1]
#pred=df6['predict_date'].str.split('9').str[0]

# %%
dfall=pd.DataFrame({'broker':broker, 'company_name':company_name, 'current_price':cp, 'recomended_buying':rb, 'predict_date':predict_date, 'target_price':tp})

# %%
dfall
# Out:
#                     broker          company_name current_price  \
# 0      Prabhudas Lilladher              Titan Co        1064.8
# 1            Dolat Capital    Gulf Oil Lubricant        782.25
# 2      Prabhudas Lilladher      Gokaldas Exports          75.7
# 3            Dolat Capital       Vinati Organics       1801.45
# 4                Sharekhan  Kalpataru PowerTrans         463.9
# 5                Sharekhan    Zydus Wellness Ltd        1444.6
# 6            Motilal Oswal         Eicher Motors       16940.6
# 7            Dolat Capital           Gujarat Gas        176.35
# 8            Dolat Capital  Kalpataru PowerTrans         463.9
# 9            Motilal Oswal   Chola Invest & Fin.        266.75
# 10     Prabhudas Lilladher         Ashok Leyland          64.4
# 11     Prabhudas Lilladher                   UPL        573.15
# 12     Prabhudas Lilladher        Container Corp         504.9
# 13        Kotak Securities       Aegis Logistics         196.7
# 14        Kotak Securities                  MOIL         134.6
# 15     Prabhudas Lilladher     Heidelberg Cement        187.95
# 16     Prabhudas Lilladher         Future Retail         407.9
# 17     Prabhudas Lilladher  Kalpataru PowerTrans         463.9
# 18     Prabhudas Lilladher      Indian Oil Corp.         135.3
# 19               Sharekhan         Bank Of India          69.7
# 20               Sharekhan         Hero MotoCorp        2401.4
# 21           Motilal Oswal         Tech Mahindra        636.35
# 22           Motilal Oswal    Bharat Electronics          95.4
# 23           Dolat Capital   Navin Fluorine Intl           642
# 24               Sharekhan             Axis Bank        673.45
# 25               Sharekhan    Bharat Electronics          95.4
# 26         HDFC Securities         Hero MotoCorp        2401.4
# 27           Dolat Capital         Castrol India        116.55
# 28           Motilal Oswal   Piramal Enterprises       1747.25
# 29           Motilal Oswal             Axis Bank        673.45
# 30        Kotak Securities  Chennai Petrol. Corp        189.45
# 31  LKP Securities Limited         Maruti Suzuki        5692.4
# 32               Sharekhan    Supreme Industries       1035.75
# 33               Sharekhan            ICICI Bank        410.75
# 34           Motilal Oswal       Music Broadcast         43.95
# 35     Prabhudas Lilladher   Chola Invest & Fin.        266.75
# 36     Prabhudas Lilladher                 NOCIL          88.6
# 37        Kotak Securities  Central Dep. Service        190.95
# 38        Kotak Securities             VIP Inds.         380.7
# 39        Kotak Securities           Gujarat Gas        176.35
# 40         HDFC Securities        Dr. Reddys Lab       2529.85
# 41         HDFC Securities  Central Dep. Service        190.95
# 42         HDFC Securities         Balaji Amines        219.05
# 43     Prabhudas Lilladher             ABB India       1359.65
# 44     Prabhudas Lilladher        Dr. Reddys Lab       2529.85
# 45         ICICIdirect.com    Mahindra Life. Dev        374.95
# 46         ICICIdirect.com    TeamLease Services          2661
#
#    recomended_buying predict_date target_price
# 0            1056.40    02 Aug 19      1267.00
# 1             771.00    01 Aug 19       883.00
# 2              80.00    01 Aug 19       116.00
# 3            1818.29    01 Aug 19      2052.00
# 4             481.56    01 Aug 19       590.00
# 5            1450.69    01 Aug 19      1780.00
# 6           16369.70    01 Aug 19     19000.00
# 7             171.45    01 Aug 19       216.00
# 8             482.95    01 Aug 19       530.00
# 9             263.29    01 Aug 19       315.00
# 10             69.90    01 Aug 19        75.00
# 11            594.50    01 Aug 19       752.00
# 12            506.00    01 Aug 19       601.00
# 13            187.05    01 Aug 19       270.00
# 14            134.90    01 Aug 19       180.00
# 15            192.45    01 Aug 19       220.00
# 16            415.00    01 Aug 19       512.00
# 17            482.95    01 Aug 19       624.00
# 18            139.30    01 Aug 19       168.00
# 19             70.70    31 Jul 19        80.00
# 20           2259.35    31 Jul 19      2550.00
# 21            640.30    31 Jul 19       770.00
# 22             98.40    31 Jul 19       130.00
# 23            598.00    31 Jul 19       834.00
# 24            706.55    31 Jul 19       860.00
# 25             98.40    31 Jul 19       140.00
# 26           2259.35    31 Jul 19      2875.00
# 27            124.45    31 Jul 19       143.00
# 28           1786.80    31 Jul 19      2400.00
# 29            706.55    31 Jul 19       825.00
# 30            195.50    31 Jul 19       208.00
# 31           5507.35    31 Jul 19      6200.00
# 32           1029.00    31 Jul 19      1200.00
# 33            424.95    31 Jul 19       550.00
# 34             46.25    31 Jul 19        65.00
# 35            241.80    31 Jul 19       322.00
# 36             85.80    31 Jul 19       199.00
# 37            192.30    31 Jul 19       225.00
# 38            385.85    31 Jul 19       460.00
# 39            163.90    31 Jul 19       194.00
# 40           2562.05    31 Jul 19      3360.00
# 41            192.30    31 Jul 19       320.00
# 42            227.50    31 Jul 19       452.00
# 43           1394.50    30 Jul 19      1296.00
# 44           2652.55    30 Jul 19      2997.00
# 45            374.85    30 Jul 19       380.00
# 46           2683.95    30 Jul 19      2990.00
