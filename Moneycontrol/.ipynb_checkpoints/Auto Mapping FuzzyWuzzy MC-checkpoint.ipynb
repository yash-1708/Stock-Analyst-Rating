# %%
import pandas as pd

from dateutil import parser
from datetime import datetime
from dateutil.relativedelta import relativedelta

import mysql.connector
from sqlalchemy import create_engine
import pandas.io.sql as psql
import sqlalchemy

# %%
database_username = 'smarsproddbuser@mbt-smars-mysql'
database_password = 'modern@1234'
database_ip       = 'mbt-smars-mysql.mysql.database.azure.com'
database_name     = 'mainschema'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name))

# %%
df = pd.read_sql('SELECT * FROM symbols', con=database_connection)

# %%
del df['index']
df
# Out:
#           SYMBOL                           NAME OF COMPANY  SERIES  \
# 0      20MICRONS                        20 Microns Limited      EQ
# 1     21STCENMGM  21st Century Management Services Limited      EQ
# 2     3IINFOTECH                       3i Infotech Limited      EQ
# 3        3MINDIA                          3M India Limited      EQ
# 4         3PLAND                  3P Land Holdings Limited      EQ
# ...          ...                                       ...     ...
# 1648   ZODJRDMKJ                   Zodiac JRD- MKJ Limited      EQ
# 1649        ZOTA                  Zota Health Care LImited      EQ
# 1650       ZUARI              Zuari Agro Chemicals Limited      EQ
# 1651   ZUARIGLOB                      Zuari Global Limited      EQ
# 1652   ZYDUSWELL                    Zydus Wellness Limited      EQ
#
#        ISIN NUMBER
# 0     INE144J01027
# 1     INE253B01015
# 2     INE748C01020
# 3     INE470A01017
# 4     INE105C01023
# ...            ...
# 1648  INE077B01018
# 1649  INE358U01012
# 1650  INE840M01016
# 1651  INE217A01012
# 1652  INE768C01010
#
# [1653 rows x 4 columns]

# %%
df2 = pd.read_sql('SELECT distinct Cmp_Name FROM mainschema.mcrecos',con=database_connection)

# %%
df2
# Out:
#                 Cmp_Name
# 0          Cox and Kings
# 1      IG Petrochemicals
# 2     Siyaram Silk Mills
# 3      JK Lakshmi Cement
# 4         Sunteck Realty
# ...                  ...
# 1169                KDDL
# 1170     Jenburkt Pharma
# 1171              Sangam
# 1172      Samkrg Pistons
# 1173                HDIL
#
# [1174 rows x 1 columns]

# %%
#!pip install fuzzywuzzy
from fuzzywuzzy import fuzz

# %%
stripped = []
for i in df2['Cmp_Name'] :
    i = i.lower()
    i = i.replace(" ","")
    i = i.replace(".","")
    i = i.replace("(i)","")
    i = i.replace("(","")
    i = i.replace(")","")
    i = i.replace("-","")
    stripped.append(i)

# %%
stripped2 = []
for i in df['NAME OF COMPANY'] :
    i = i.lower()
    i = i.replace(" ","")
    i = i.replace(".","")
    i = i.replace("(i)","")
    i = i.replace("(","")
    i = i.replace(")","")
    i = i.replace("-","")
    stripped2.append(i)

# %%
y=0
z=0
ilist=[]
matchlist=[]
iNotFoundList=[]
for i in stripped:
    x=0
    for j in stripped2:
        Partial_Ratio = fuzz.partial_ratio(i,j)
        if Partial_Ratio > 85:
            x=x+1
            match = j
            matchratio = Partial_Ratio
    if x==1:
        print(i,"||",match,"||",matchratio)
        ilist.append(i)
        matchlist.append(match)
        y=y+1
    else:
        iNotFoundList.append(i)
        z=z+1
# Out:
# siyaramsilkmills || siyaramsilkmillslimited || 100
# jklakshmicement || jklakshmicementlimited || 100
# sunteckrealty || sunteckrealtylimited || 100
# himadrispeciality || himadrispecialitychemicallimited || 100
# shreepushkarchemicals || shreepushkarchemicals&fertiliserslimited || 100
# natcopharma || natcopharmalimited || 100
# marutisuzukiindia || marutisuzukiindialimited || 100
# coromandelinternational || coromandelinternationallimited || 100
# ashokleyland || ashokleylandlimited || 100
# mirzainternational || mirzainternationallimited || 100
# aartidrugs || aartidrugslimited || 100
# nbcc || nbccindialimited || 100
# thermax || thermaxlimited || 100
# vardhmantextiles || vardhmantextileslimited || 100
# unitedbreweries || unitedbrewerieslimited || 100
# bankofbaroda || bankofbaroda || 100
# ahluwaliacontractsindia || ahluwaliacontractsindialimited || 100
# finolexcables || finolexcableslimited || 100
# pncinfratech || pncinfratechlimited || 100
# apollotyres || apollotyreslimited || 100
# starcement || starcementlimited || 100
# deccancements || deccancementslimited || 100
# mindtree || mindtreelimited || 100
# federalbank || thefederalbanklimited || 100
# vatechwabag || vatechwabaglimited || 100
# repcohomefinance || repcohomefinancelimited || 100
# suprajitengineering || suprajitengineeringlimited || 100
# sadbhavengineering || sadbhavengineeringlimited || 100
# lemontree || lemontreehotelslimited || 100
# ahluwaliacontracts || ahluwaliacontractsindialimited || 100
# jklakshmicements || jklakshmicementlimited || 94
# raymond || raymondlimited || 100
# vedanta || vedantalimited || 100
# reliancecommunications || reliancecommunicationslimited || 100
# filatexindia || filatexindialimited || 100
# mahanagargas || mahanagargaslimited || 100
# sterlingtools || sterlingtoolslimited || 100
# marutisuzuki || marutisuzukiindialimited || 100
# nmdc || nmdclimited || 100
# aurobindopharma || aurobindopharmalimited || 100
# nrbbearings || nrbbearinglimited || 91
# kaveriseedco || kaveriseedcompanylimited || 100
# futureretail || futureretaillimited || 100
# canarabank || canarabank || 100
# ncc || ncclimited || 100
# dilipbuildcon || dilipbuildconlimited || 100
# daburindia || daburindialimited || 100
# indianhotels || theindianhotelscompanylimited || 100
# orientcement || orientcementlimited || 100
# glenmark || glenmarkpharmaceuticalslimited || 100
# brigadeenterprises || brigadeenterpriseslimited || 100
# jkumarinfraprojects || jkumarinfraprojectslimited || 100
# insecticidesindia || insecticidesindialimited || 100
# gulfoillubricants || gulfoillubricantsindialimited || 100
# jamnaauto || jamnaautoindustrieslimited || 100
# grindwellnorton || grindwellnortonlimited || 100
# visakaindustries || visakaindustrieslimited || 100
# voltamptransformers || voltamptransformerslimited || 100
# gabrielindia || gabrielindialimited || 100
# orientalcarbonandchemicals || orientalcarbon&chemicalslimited || 88
# suntvnetwork || suntvnetworklimited || 100
# careratings || careratingslimited || 100
# britanniaindustries || britanniaindustrieslimited || 100
# indraprasthagas || indraprasthagaslimited || 100
# heidelbergcementindia || heidelbergcementindialimited || 100
# prataapsnacks || prataapsnackslimited || 100
# titancompany || titancompanylimited || 100
# marico || maricolimited || 100
# unitedspirits || unitedspiritslimited || 100
# hexawaretechnologies || hexawaretechnologieslimited || 100
# thyrocaretechnologies || thyrocaretechnologieslimited || 100
# entertainmentnetworkindia || entertainmentnetworkindialimited || 100
# sonatasoftware || sonatasoftwarelimited || 100
# gujaratgas || gujaratgaslimited || 100
# petronetlng || petronetlnglimited || 100
# graphiteindia || graphiteindialimited || 100
# futureconsumer || futureconsumerlimited || 100
# srf || srflimited || 100
# tatacommunications || tatacommunicationslimited || 100
# suntv || suntvnetworklimited || 100
# cadilahealth || cadilahealthcarelimited || 100
# ashokabuildcon || ashokabuildconlimited || 100
# cityunionbank || cityunionbanklimited || 100
# bharatforge || bharatforgelimited || 100
# torrentpharmaceuticals || torrentpharmaceuticalslimited || 100
# transportcorporation || transportcorporationofindialimited || 100
# hindalcoindustries || hindalcoindustrieslimited || 100
# endurancetechnologies || endurancetechnologieslimited || 100
# tciexpress || tciexpresslimited || 100
# powergridcorporation || powergridcorporationofindialimited || 100
# ratnamanimetals || ratnamanimetals&tubeslimited || 100
# cadilahealthcare || cadilahealthcarelimited || 100
# tvtodaynetwork || tvtodaynetworklimited || 100
# voltas || voltaslimited || 100
# khadimindia || khadimindialimited || 100
# pspprojects || pspprojectslimited || 100
# relaxofootwear || relaxofootwearslimited || 100
# adityabirlacapital || adityabirlacapitallimited || 100
# phoenixmills || thephoenixmillslimited || 100
# entertainmentnetworkindia || entertainmentnetworkindialimited || 100
# powergrid || powergridcorporationofindialimited || 100
# torrentpower || torrentpowerlimited || 100
# pvr || pvrlimited || 100
# kajariaceramics || kajariaceramicslimited || 100
# kotakmahindrabank || kotakmahindrabanklimited || 100
# bajajauto || bajajautolimited || 100
# sterlitetechnologies || sterlitetechnologieslimited || 100
# erosinternationalmedia || erosinternationalmedialimited || 100
# bataindia || bataindialimited || 100
# sequentscientific || sequentscientificlimited || 100
# icicilombard || icicilombardgeneralinsurancecompanylimited || 100
# musicbroadcast || musicbroadcastlimited || 100
# majesco || majescolimited || 100
# sagarcements || sagarcementslimited || 100
# icicibank || icicibanklimited || 100
# agrotechfoods || agrotechfoodslimited || 100
# bergerpaints || bergerpaintslimited || 100
# karurvysyabank || karurvysyabanklimited || 100
# vinatiorganics || vinatiorganicslimited || 100
# centraldepositoryservices || centraldepositoryservicesindialimited || 100
# cromptongreavesconsumerelectricals || cromptongreavesconsumerelectricalslimited || 100
# shriramtransportfinance || shriramtransportfinancecompanylimited || 100
# subros || subroslimited || 100
# ceat || ceatlimited || 100
# kajaria || kajariaceramicslimited || 100
# zensartechnologies || zensartechnologieslimited || 100
# quesscorp || quesscorplimited || 100
# hesterbiosciences || hesterbioscienceslimited || 100
# bhartiairtel || bhartiairtellimited || 100
# nestléindia || nestleindialimited || 91
# drreddy’slaboratories || drreddy'slaboratorieslimited || 95
# bharatelectronics || bharatelectronicslimited || 100
# jswsteel || jswsteellimited || 100
# wipro || wiprolimited || 100
# l&ttechnology || l&ttechnologyserviceslimited || 100
# dishtvindia || dishtvindialimited || 100
# piramalenterprises || piramalenterpriseslimited || 100
# jubilantfoodworks || jubilantfoodworkslimited || 100
# mahindrafinance || mahindra&mahindrafinancialserviceslimited || 93
# ttkprestige || ttkprestigelimited || 100
# syngeneinternational || syngeneinternationallimited || 100
# rallisindia || rallisindialimited || 100
# radicokhaitan || radicokhaitanlimited || 100
# heidelbergcementindia || heidelbergcementindialimited || 100
# ambujacement || ambujacementslimited || 100
# oberoirealty || oberoirealtylimited || 100
# bajajfinance || bajajfinancelimited || 100
# mahindrafinancialservices || mahindra&mahindrafinancialserviceslimited || 100
# ambujacements || ambujacementslimited || 100
# bajajfinserv || bajajfinservlimited || 100
# hcltech || hcltechnologieslimited || 100
# asianpaints || asianpaintslimited || 100
# multicommodityexchange || multicommodityexchangeofindialimited || 100
# iciciprudentiallife || iciciprudentiallifeinsurancecompanylimited || 100
# jubilantlifesciences || jubilantlifescienceslimited || 100
# persistentsystems || persistentsystemslimited || 100
# heromotocorp || heromotocorplimited || 100
# iciciprudentiallifeinsurancecompany || iciciprudentiallifeinsurancecompanylimited || 100
# colgatepalmolive || colgatepalmoliveindialimited || 100
# zeeentertainmententerprises || zeeentertainmententerpriseslimited || 100
# hindustanzinc || hindustanzinclimited || 100
# cyient || cyientlimited || 100
# inoxleisure || inoxleisurelimited || 100
# ultratechcement || ultratechcementlimited || 100
# hdfcbank || hdfcbanklimited || 100
# aegislogistics || aegislogisticslimited || 100
# sbilife || sbilifeinsurancecompanylimited || 100
# bhageriaindustries || bhageriaindustrieslimited || 100
# varrocengineering || varrocengineeringlimited || 100
# trident || tridentlimited || 100
# mphasis || mphasislimited || 100
# genuspowerinfrastructure || genuspowerinfrastructureslimited || 100
# karnatakabank || thekarnatakabanklimited || 100
# cumminsindia || cumminsindialimited || 100
# sunpharmaceuticalindustries || sunpharmaceuticalindustrieslimited || 100
# havells || havellsindialimited || 100
# mahindracieautomotive || mahindracieautomotivelimited || 100
# havellsindia || havellsindialimited || 100
# indusindbank || indusindbanklimited || 100
# ausmallfinancebank || ausmallfinancebanklimited || 100
# zeemedia || zeemediacorporationlimited || 100
# navneeteducation || navneeteducationlimited || 100
# cochinshipyard || cochinshipyardlimited || 100
# indostarcapitalfinance || indostarcapitalfinancelimited || 100
# hindustanunilever || hindustanunileverlimited || 100
# indiabullshousingfinance || indiabullshousingfinancelimited || 100
# deltacorp || deltacorplimited || 100
# equitasholdings || equitasholdingslimited || 100
# larsen&toubroinfotech || larsen&toubroinfotechlimited || 100
# nucleussoftware || nucleussoftwareexportslimited || 100
# pnbhousing || pnbhousingfinancelimited || 100
# avenuesupermarts || avenuesupermartslimited || 100
# centurytextilesandindustries || centurytextiles&industrieslimited || 89
# beml || bemllimited || 100
# l&ttechnologyservices || l&ttechnologyserviceslimited || 100
# pidiliteindustries || pidiliteindustrieslimited || 100
# adityabirlafashion || adityabirlafashionandretaillimited || 100
# zeelearn || zeelearnlimited || 100
# tataconsultancyservices || tataconsultancyserviceslimited || 100
# hikal || hikallimited || 100
# meghmaniorganics || meghmaniorganicslimited || 100
# dhampursugar || dhampursugarmillslimited || 100
# pfizer || pfizerlimited || 100
# zeeentertainment || zeeentertainmententerpriseslimited || 100
# tataelxsi || tataelxsilimited || 100
# cipla || ciplalimited || 100
# mothersonsumisystems || mothersonsumisystemslimited || 100
# dishmancarbogenamcis || dishmancarbogenamcislimited || 100
# ntpc || ntpclimited || 100
# tatachemicals || tatachemicalslimited || 100
# chennaipetroleumcorporation || chennaipetroleumcorporationlimited || 100
# eichermotors || eichermotorslimited || 100
# deepaknitrite || deepaknitritelimited || 100
# kardaconstruction || kardaconstructionslimited || 100
# jamnaautoindustries || jamnaautoindustrieslimited || 100
# mmforgings || mmforgingslimited || 100
# adityabirlafashionandretail || adityabirlafashionandretaillimited || 100
# techmahindra || techmahindralimited || 100
# tvsmotorcompany || tvsmotorcompanylimited || 100
# reliancenipponlifeassetmanagement || reliancenipponlifeassetmanagementlimited || 100
# dlinkindia || dlinkindialimited || 100
# divislaboratories || divi'slaboratorieslimited || 94
# biocon || bioconlimited || 100
# godfreyphillips || godfreyphillipsindialimited || 100
# reliancehomefinance || reliancehomefinancelimited || 100
# apollohospitals || apollohospitalsenterpriselimited || 100
# reliancecapital || reliancecapitallimited || 100
# sandhartechnologies || sandhartechnologieslimited || 100
# shemarooentertainment || shemarooentertainmentlimited || 100
# adaniportandsez || adaniportsandspecialeconomiczonelimited || 87
# oraclefinancialservicessoftware || oraclefinancialservicessoftwarelimited || 100
# icicilombardgeneralinsurance || icicilombardgeneralinsurancecompanylimited || 100
# crestventures || crestventureslimited || 100
# lupin || lupinlimited || 100
# akzonobelindia || akzonobelindialimited || 100
# nhpc || nhpclimited || 100
# mahindraandmahindrafinancial || mahindra&mahindrafinancialserviceslimited || 89
# gujaratfluorochemicals || gujaratfluorochemicalslimited || 100
# grasimindustries || grasimindustrieslimited || 100
# centurytextiles&industries || centurytextiles&industrieslimited || 100
# manappuramfinance || manappuramfinancelimited || 100
# greavescotton || greavescottonlimited || 100
# indostarcapital || indostarcapitalfinancelimited || 100
# ptcindiafinancialservices || ptcindiafinancialserviceslimited || 100
# cholamandalaminvestmentandfinancecompany || cholamandalaminvestmentandfinancecompanylimited || 100
# shaktipumpsindia || shaktipumpsindialimited || 100
# bajajholdingsandinvestment || bajajholdings&investmentlimited || 88
# shardacropchem || shardacropchemlimited || 100
# thephoenixmills || thephoenixmillslimited || 100
# skipper || skipperlimited || 100
# bharatheavyelectricals || bharatheavyelectricalslimited || 100
# simplexinfrastructure || simplexinfrastructureslimited || 100
# pokarna || pokarnalimited || 100
# maharashtraseamless || maharashtraseamlesslimited || 100
# magmafincorp || magmafincorplimited || 100
# vasconengineers || vasconengineerslimited || 100
# voltamp || voltamptransformerslimited || 100
# asterdmhealthcare || asterdmhealthcarelimited || 100
# wockhardt || wockhardtlimited || 100
# himadrispecialitychemical || himadrispecialitychemicallimited || 100
# gtplhathway || gtplhathwaylimited || 100
# l&tfinanceholdings || l&tfinanceholdingslimited || 100
# amararajabatteries || amararajabatterieslimited || 100
# timkenindia || timkenindialimited || 100
# ppapautomotive || ppapautomotivelimited || 100
# sundramfasteners || sundramfastenerslimited || 100
# neulandlabs || neulandlaboratorieslimited || 91
# alkemlabs || alkemlaboratorieslimited || 89
# mothersonsumisystem || mothersonsumisystemslimited || 100
# jkumarinfraprojects || jkumarinfraprojectslimited || 100
# koltepatildevelopers || koltepatildeveloperslimited || 100
# ineosstyrolution || ineosstyrolutionindialimited || 100
# trent || trentlimited || 100
# varunbeverage || varunbeverageslimited || 100
# jmcprojects || jmcprojectsindialimited || 100
# hindustanpetroleumcorporation || hindustanpetroleumcorporationlimited || 100
# sobha || sobhalimited || 100
# suzlonenergy || suzlonenergylimited || 100
# kalpatarupower || kalpatarupowertransmissionlimited || 100
# phillipscarbonblack || phillipscarbonblacklimited || 100
# kansainerolacpaints || kansainerolacpaintslimited || 100
# intellectdesignarena || intellectdesignarenalimited || 100
# kansainerolac || kansainerolacpaintslimited || 100
# relaxofootwears || relaxofootwearslimited || 100
# firstsourcesolutions || firstsourcesolutionslimited || 100
# timetechnoplast || timetechnoplastlimited || 100
# moldtekpackaging || moldtekpackaginglimited || 100
# muthootfinance || muthootfinancelimited || 100
# indiacements || theindiacementslimited || 100
# hatsunagroproduct || hatsunagroproductlimited || 100
# infoedge || infoedgeindialimited || 100
# lumaxautotech || lumaxautotechnologieslimited || 100
# vguard || vguardindustrieslimited || 100
# thangamayil || thangamayiljewellerylimited || 100
# jagranprakashan || jagranprakashanlimited || 100
# jklakshmicement || jklakshmicementlimited || 100
# lauruslabs || lauruslabslimited || 100
# vguard || vguardindustrieslimited || 100
# supremeindustries || supremeindustrieslimited || 100
# kalyanisteels || kalyanisteelslimited || 100
# swarajengines || swarajengineslimited || 100
# orientalcarbon&amp;chemicals || orientalcarbon&chemicalslimited || 86
# mmforgings || mmforgingslimited || 100
# jkpaper || jkpaperlimited || 100
# sicallogistics || sicallogisticslimited || 100
# westlifedevelopment || westlifedevelopmentltd || 100
# prestigeestateprojects || prestigeestatesprojectslimited || 95
# tatametaliks || tatametalikslimited || 100
# suntvnetworks || suntvnetworklimited || 92
# jetairways || jetairwaysindialimited || 100
# drreddy'slabs || drreddy'slaboratorieslimited || 92
# cholamandalaminvestment&amp;finance || cholamandalaminvestmentandfinancecompanylimited || 89
# shriramcityunionfinance || shriramcityunionfinancelimited || 100
# navinfluorineinternational || navinfluorineinternationallimited || 100
# heidelbergcements || heidelbergcementindialimited || 94
# evereadyindustries || evereadyindustriesindialimited || 100
# petronetlngltd || petronetlnglimited || 86
# containercorporationofindia || containercorporationofindialimited || 100
# cholamandalaminvestment&amp;financecompany || cholamandalaminvestmentandfinancecompanylimited || 90
# symphony || symphonylimited || 100
# colgatepalmoliveindia || colgatepalmoliveindialimited || 100
# sagarcement || sagarcementslimited || 100
# shemarooentertainments || shemarooentertainmentlimited || 95
# tatapower || tatapowercompanylimited || 100
# cromptongreavesconsumer || cromptongreavesconsumerelectricalslimited || 100
# drreddy’slaboratories || drreddy'slaboratorieslimited || 95
# esselpropack || esselpropacklimited || 100
# teamleaseservices || teamleaseserviceslimited || 100
# britannia || britanniaindustrieslimited || 100
# mothersonsumi || mothersonsumisystemslimited || 100
# dbcorp || dbcorplimited || 100
# vmartretail || vmartretaillimited || 100
# drlalpathlabs || drlalpathlabsltd || 100
# suvenlifesciences || suvenlifescienceslimited || 100
# suvenlifesciences || suvenlifescienceslimited || 100
# adaniports || adaniportsandspecialeconomiczonelimited || 100
# kaveriseed || kaveriseedcompanylimited || 100
# castrolindia || castrolindialimited || 100
# thirumalaichemicals || thirumalaichemicalslimited || 100
# jbmauto, || jbmautolimited || 88
# asainpaints || asianpaintslimited || 91
# v2retail || v2retaillimited || 100
# indianoilcorporation || indianoilcorporationlimited || 100
# prabhatdairy || prabhatdairylimited || 100
# adanienterprises || adanienterpriseslimited || 100
# godrejconsumer || godrejconsumerproductslimited || 100
# itdcementation || itdcementationindialimited || 100
# indocountindustries || indocountindustrieslimited || 100
# canfinhomes || canfinhomeslimited || 100
# divi'slaboratories || divi'slaboratorieslimited || 100
# sundaramfasteners || sundramfastenerslimited || 94
# godrejindustries || godrejindustrieslimited || 100
# centuryplyboards || centuryplyboardsindialimited || 100
# jindalsteel&power || jindalsteel&powerlimited || 100
# drreddyslaboratories || drreddy'slaboratorieslimited || 95
# capacit’einfraprojects || capacit'einfraprojectslimited || 95
# godrejconsumerproducts || godrejconsumerproductslimited || 100
# bhartiinfratel || bhartiinfratellimited || 100
# evereadyindustriesindia || evereadyindustriesindialimited || 100
# avantifeeds || avantifeedslimited || 100
# iciciprudentiallifeinsurance || iciciprudentiallifeinsurancecompanylimited || 100
# schandandcompany || schandandcompanylimited || 100
# bharatpetroleumcorporation || bharatpetroleumcorporationlimited || 100
# torrentpharma || torrentpharmaceuticalslimited || 100
# glenmarkpharma || glenmarkpharmaceuticalslimited || 100
# astramicrowaveproducts || astramicrowaveproductslimited || 100
# capaciteinfraprojects || capacit'einfraprojectslimited || 95
# ifglrefractories || ifglrefractorieslimited || 100
# mahindraholidaysandresortsindia || mahindraholidays&resortsindialimited || 90
# shankarabuildingproducts || shankarabuildingproductslimited || 100
# tejasnetworks || tejasnetworkslimited || 100
# shoppersstop || shoppersstoplimited || 100
# jyothylabs || jyothylabslimited || 100
# ghcl || ghcllimited || 100
# hindustannationalglass&industries || hindusthannationalglass&industrieslimited || 97
# navabharatventures || navabharatventureslimited || 100
# justdial || justdiallimited || 100
# cholamandalaminvestment || cholamandalaminvestmentandfinancecompanylimited || 100
# heritagefoods || heritagefoodslimited || 100
# chennaipetroleum || chennaipetroleumcorporationlimited || 100
# powergridcorp || powergridcorporationofindialimited || 100
# camlinfinesciences || camlinfinescienceslimited || 100
# paragmilk || paragmilkfoodslimited || 100
# jkumarinfraprojects || jkumarinfraprojectslimited || 100
# powergridcorporationofindia || powergridcorporationofindialimited || 100
# bajajelectricals || bajajelectricalslimited || 100
# kardaconstructions || kardaconstructionslimited || 100
# technoelectric || technoelectric&engineeringcompanylimited || 100
# deepaknitriteltd || deepaknitritelimited || 88
# dishtv || dishtvindialimited || 100
# centurytextiles || centurytextiles&industrieslimited || 100
# mayuruniquoters || mayuruniquotersltd || 100
# granulesindia || granulesindialimited || 100
# sarlaperformancefibers || sarlaperformancefiberslimited || 100
# laopalarg || laopalarglimited || 100
# satincreditcare || satincreditcarenetworklimited || 100
# indocoremedies || indocoremedieslimited || 100
# astramicrowave || astramicrowaveproductslimited || 100
# lakshmivilasbank || lakshmivilasbanklimited || 100
# gatewaydistriparks || gatewaydistriparkslimited || 100
# himatsingkaseide || himatsingkaseidelimited || 100
# somanyceramics || somanyceramicslimited || 100
# godrejagrovet || godrejagrovetlimited || 100
# ramkrishnaforgings || ramkrishnaforgingslimited || 100
# wonderlaholidays || wonderlaholidayslimited || 100
# zuariagrochemicals || zuariagrochemicalslimited || 100
# dabur || daburindialimited || 100
# indiacement || theindiacementslimited || 100
# blsinternationalservices || blsinternationalserviceslimited || 100
# drreddy'slaboratories || drreddy'slaboratorieslimited || 100
# tatacoffee || tatacoffeelimited || 100
# actionconstructionequipment || actionconstructionequipmentlimited || 100
# redingtonindia || redingtonindialimited || 100
# asiangranito || asiangranitoindialimited || 100
# cclproducts || cclproductsindialimited || 100
# indianhotelscompany || theindianhotelscompanylimited || 100
# balkrishnaindustries || balkrishnaindustrieslimited || 100
# orientrefractories || orientrefractorieslimited || 100
# futurelifestylefashion || futurelifestylefashionslimited || 100
# ramasteeltubes || ramasteeltubeslimited || 100
# rajooengineers || prajayengineerssyndicatelimited || 86
# keiindustries || keiindustrieslimited || 100
# newindiaassurancecompany || thenewindiaassurancecompanylimited || 100
# nilkamal || nilkamallimited || 100
# redingtonindia || redingtonindialimited || 100
# balrampurchini || balrampurchinimillslimited || 100
# mcxindia || maxindialimited || 88
# theramcocement || theramcocementslimited || 100
# hpcl || nhpclimited || 100
# allcargologistics || allcargologisticslimited || 100
# cromptongreavesconsumerelectrical || cromptongreavesconsumerelectricalslimited || 100
# tajgvkhotels || tajgvkhotels&resortslimited || 100
# mangalorerefinery || mangalorerefineryandpetrochemicalslimited || 100
# gujaratpipavavport || gujaratpipavavportlimited || 100
# welspunindia || welspunindialimited || 100
# abbottindia || abbottindialimited || 100
# alkylamines || alkylamineschemicalslimited || 100
# birlacorporation || birlacorporationlimited || 100
# dbcorp || dbcorplimited || 100
# solarindustriesindia || solarindustriesindialimited || 100
# godrejproperties || godrejpropertieslimited || 100
# adaniportsandsez || adaniportsandspecialeconomiczonelimited || 94
# hindustanoilexploration || hindustanoilexplorationcompanylimited || 100
# ifbindustries || ifbindustrieslimited || 100
# containercorporation || containercorporationofindialimited || 100
# interglobeaviation || interglobeaviationlimited || 100
# ruchirapapers || ruchirapaperslimited || 100
# newgensoftware || newgensoftwaretechnologieslimited || 100
# jindalstainlesshisar || jindalstainlesshisarlimited || 100
# mahindralifespacedevelopers || mahindralifespacedeveloperslimited || 100
# dewanhousingfinancecorporation || dewanhousingfinancecorporationlimited || 100
# tataglobalbeverage || tataglobalbeverageslimited || 100
# shreecement || shreecementlimited || 100
# reliancenipponlifeasset || reliancenipponlifeassetmanagementlimited || 100
# mahindralifespace || mahindralifespacedeveloperslimited || 100
# housingdevelopmentfinancecorporation || housingdevelopmentfinancecorporationlimited || 100
# shreecements || shreecementlimited || 92
# indianhumepipecompany || indianhumepipecompanylimited || 100
# archidplyindustries || archidplyindustrieslimited || 100
# vinylchemicals || vinylchemicalsindialimited || 100
# salasartechno || salasartechnoengineeringlimited || 100
# kewalkiranclothing || kewalkiranclothinglimited || 100
# cholamandalaminvestment&finance || cholamandalaminvestmentandfinancecompanylimited || 90
# cholamandalaminvestments, || cholamandalaminvestmentandfinancecompanylimited || 92
# thomascook || thomascookindialimited || 100
# mahindracie || mahindracieautomotivelimited || 100
# paragmilkfoods || paragmilkfoodslimited || 100
# nationalaluminiumcompany || nationalaluminiumcompanylimited || 100
# schaefflerindia || schaefflerindialimited || 100
# fairchemspeciality || fairchemspecialitylimited || 100
# kalpatarupowertransmission || kalpatarupowertransmissionlimited || 100
# ramcocements || theramcocementslimited || 100
# futuresupplychain || futuresupplychainsolutionslimited || 100
# shalby || shalbylimited || 100
# futuresupplychainsolutions || futuresupplychainsolutionslimited || 100
# pcjeweller || pcjewellerlimited || 100
# mishradhatu || mishradhatunigamlimited || 100
# nocil || nocillimited || 100
# jswenergy || jswenergylimited || 100
# edelweissfinancialservices || edelweissfinancialserviceslimited || 100
# gujaratambujaexports || gujaratambujaexportslimited || 100
# hindustanaeronautics || hindustanaeronauticslimited || 100
# icicisecurities || icicisecuritieslimited || 100
# bharatdynamics || bharatdynamicslimited || 100
# lemontreehotels || lemontreehotelslimited || 100
# jaicorp || jaicorplimited || 100
# bhagyanagarindia || bhagyanagarindialimited || 100
# bombaydyeing || bombaydyeing&mfgcompanylimited || 100
# deepakfertilizers || deepakfertilizersandpetrochemicalscorporationlimited || 100
# indiabullsventures || indiabullsventureslimited || 100
# mahindra&mahindrafinancialservices || mahindra&mahindrafinancialserviceslimited || 100
# bhansaliengineeringpolymers || bhansaliengineeringpolymerslimited || 100
# sreiinfrastructurefinance || sreiinfrastructurefinancelimited || 100
# aurionprosolutions || aurionprosolutionslimited || 100
# gravitaindia || gravitaindialimited || 100
# spicejet || spicejetltd || 100
# indiabullsrealestate || indiabullsrealestatelimited || 100
# bluestar || bluestarlimited || 100
# hsil || hsillimited || 100
# ajantapharma || ajantapharmalimited || 100
# shilpamedicare || shilpamedicarelimited || 100
# gail || gailindialimited || 100
# talbrosautomotivecomponents || talbrosautomotivecomponentslimited || 100
# gujaratstatepetronet || gujaratstatepetronetlimited || 100
# securityandintelligenceservices || securityandintelligenceservicesindialimited || 100
# krbl || krbllimited || 100
# rushildecor || rushildecorlimited || 100
# colgatepalmolive || colgatepalmoliveindialimited || 100
# apexfrozenfoods || apexfrozenfoodslimited || 100
# oraclefinancial || oraclefinancialservicessoftwarelimited || 100
# vivimedlabsltd || vivimedlabslimited || 86
# fortishealthcare || fortishealthcarelimited || 100
# kansainerolacpaintsltd || kansainerolacpaintslimited || 91
# musicbroadcastltd || musicbroadcastlimited || 88
# polyplexcorporation || polyplexcorporationlimited || 100
# adlabsentertainment || adlabsentertainmentlimited || 100
# varunbeverages || varunbeverageslimited || 100
# icra || icralimited || 100
# crisil || crisillimited || 100
# dlf || dlflimited || 100
# sadbhavengineerings || sadbhavengineeringlimited || 95
# cromptongreaves || cromptongreavesconsumerelectricalslimited || 100
# carborundumuniversalltd || carborundumuniversallimited || 91
# marksanspharma || marksanspharmalimited || 100
# emmbiindustries || emmbiindustrieslimited || 100
# theramcocements || theramcocementslimited || 100
# persistentsystemsltd || persistentsystemslimited || 90
# entertainmentnetwork || entertainmentnetworkindialimited || 100
# alkylamineschemicals || alkylamineschemicalslimited || 100
# bluedartexpress || bluedartexpresslimited || 100
# navkarcorporation || navkarcorporationlimited || 100
# gskpharma || blissgvspharmalimited || 89
# cromptongreavescons || cromptongreavesconsumerelectricalslimited || 100
# talwalkarsbettervaluefitness || talwalkarsbettervaluefitnesslimited || 100
# shriramtransport || shriramtransportfinancecompanylimited || 100
# drreddy'slaboratories || drreddy'slaboratorieslimited || 100
# idfcbank || hdfcbanklimited || 88
# shkelkarandco || shkelkarandcompanylimited || 100
# orientalcarbon&chemicals || orientalcarbon&chemicalslimited || 100
# ujjivanfinancialservices || ujjivanfinancialserviceslimited || 100
# dhanukaagritech || dhanukaagritechlimited || 100
# blissgvspharma || blissgvspharmalimited || 100
# coromandelintl || coromandelinternationallimited || 93
# schandandcompanyltd || schandandcompanylimited || 89
# bharatbijlee || bharatbijleelimited || 100
# alkemlaboratories || alkemlaboratorieslimited || 100
# whirlpoolofindia || whirlpoolofindialimited || 100
# sterlitetechnologiesltd || sterlitetechnologieslimited || 91
# eidparry || eidparryindialimited || 100
# gujaratnarmadavalley || gujaratnarmadavalleyfertilizersandchemicalslimited || 100
# birlacorp || birlacorporationlimited || 100
# smlisuzu || smlisuzulimited || 100
# snowmanlogisticsltd || snowmanlogisticslimited || 89
# punjabnationalbank || punjabnationalbank || 100
# apcotexindustries || apcotexindustrieslimited || 100
# drreddy’slaboratories || drreddy'slaboratorieslimited || 95
# equitasholding || equitasholdingslimited || 100
# hindustanconstructioncompany || hindustanconstructioncompanylimited || 100
# mahindraholidaysandresorts || mahindraholidays&resortsindialimited || 88
# cclproductsindia || cclproductsindialimited || 100
# gnaaxles || gnaaxleslimited || 100
# cgconsumerelectricals || cromptongreavesconsumerelectricalslimited || 90
# zuariagrochemicals || zuariagrochemicalslimited || 100
# mahindraandmahindrafinancialservices || mahindra&mahindrafinancialserviceslimited || 92
# erislifesciences || erislifescienceslimited || 100
# allcargo || allcargologisticslimited || 100
# bajajholdings || bajajholdings&investmentlimited || 100
# ultratechcements || ultratechcementlimited || 94
# bluedartexpress || bluedartexpresslimited || 100
# tv18broadcast || tv18broadcastlimited || 100
# bajajholdingsinvestments || bajajholdings&investmentlimited || 96
# capriglobalcapital || capriglobalcapitallimited || 100
# westcoastpapermills || westcoastpapermillslimited || 100
# lypsagems&jewellery || lypsagems&jewellerylimited || 100
# mahindraholidays || mahindraholidays&resortsindialimited || 100
# mindacorp || mindacorporationlimited || 100
# futurelifestylefashions || futurelifestylefashionslimited || 100
# vakrangee || vakrangeelimited || 100
# nitinspinners || nitinspinnerslimited || 100
# gmmpfaudler || gmmpfaudlerlimited || 100
# aurobindo || aurobindopharmalimited || 100
# cadila || cadilahealthcarelimited || 100
# apollohospitalsenterprise || apollohospitalsenterpriselimited || 100
# deepakfertiliser || deepakfertilizersandpetrochemicalscorporationlimited || 94
# simplexinfrastructures || simplexinfrastructureslimited || 100
# shkelkarandco || shkelkarandcompanylimited || 100
# paragmilkfoodsltd || paragmilkfoodslimited || 88
# astralpolytechnik || astralpolytechniklimited || 100
# glenmarkpharmaceuticals || glenmarkpharmaceuticalslimited || 100
# controlprint || controlprintlimited || 100
# bluedart || bluedartexpresslimited || 100
# infoedgeindia || infoedgeindialimited || 100
# supremepetrochem || supremepetrochemlimited || 100
# jammu&kashmirbank || thejammu&kashmirbanklimited || 100
# alembicpharma || alembicpharmaceuticalslimited || 100
# forcemotors || forcemotorsltd || 100
# hindustanmediaventures || hindustanmediaventureslimited || 100
# jubilantfoodworks || jubilantfoodworkslimited || 100
# zyduswellness || zyduswellnesslimited || 100
# bajajfinanceltd || bajajfinancelimited || 87
# housingandurbandevelopmentcorporation || housing&urbandevelopmentcorporationlimited || 92
# igpetrochemicalsltd || igpetrochemicalslimited || 89
# orientalcarbon || orientalcarbon&chemicalslimited || 100
# vesuviusindia || vesuviusindialimited || 100
# manpasandbeverages || manpasandbeverageslimited || 100
# wabcoindia || wabcoindialimited || 100
# apollohospitalsenterprises || apollohospitalsenterpriselimited || 96
# heidelbergcement || heidelbergcementindialimited || 100
# moil || moillimited || 100
# koltepatildevelopers || koltepatildeveloperslimited || 100
# oil&naturalgascorp || oil&naturalgascorporationlimited || 100
# hindustanpetroleumcorp || hindustanpetroleumcorporationlimited || 100
# jktyre&industries || jktyre&industrieslimited || 100
# technocraftindustries || technocraftindustriesindialimited || 100
# mahindraholidays&resortsindia || mahindraholidays&resortsindialimited || 100
# finolexindustries || finolexindustrieslimited || 100
# technoelectric&engineering || technoelectric&engineeringcompanylimited || 100
# rupa&company || rupa&companylimited || 100
# vsttillerstractors || vsttillerstractorslimited || 100
# healthcareglobalenterprises || healthcareglobalenterpriseslimited || 100
# titagarhwagons || titagarhwagonslimited || 100
# triveniturbine || triveniturbinelimited || 100
# mahindraholidays&resorts || mahindraholidays&resortsindialimited || 100
# glaxosmithklineconsumerhealthcare || glaxosmithklineconsumerhealthcarelimited || 100
# atulauto || atulautolimited || 100
# mangalamcement || mangalamcementlimited || 100
# balajiamines || balajiamineslimited || 100
# colgate || colgatepalmoliveindialimited || 100
# carborundumuniversal || carborundumuniversallimited || 100
# p&ghygieneandhealthcare || procter&gamblehygieneandhealthcarelimited || 87
# dewanhousing || dewanhousingfinancecorporationlimited || 100
# nationalfertilizers || nationalfertilizerslimited || 100
# transportcorporationindia || transportcorporationofindialimited || 92
# dewanhousingfinance || dewanhousingfinancecorporationlimited || 100
# cholamandalaminvestmentandfinance || cholamandalaminvestmentandfinancecompanylimited || 100
# lgbalakrishnan&bros || lgbalakrishnan&broslimited || 100
# dlink || dlinkindialimited || 100
# bancoproducts || bancoproductslimited || 100
# inoxwinds || inoxwindlimited || 89
# vikasecotech || vikasecotechlimited || 100
# steelstripswheels || steelstripswheelslimited || 100
# gayatriprojects || gayatriprojectslimited || 100
# bykehospitality || thebykehospitalityltd || 100
# powerfinancecorp || powerfinancecorporationlimited || 100
# advancedenzymetechnologies || advancedenzymetechnologieslimited || 100
# equitas || equitasholdingslimited || 100
# sanghvimovers || sanghvimoverslimited || 100
# spapparels || spapparelslimited || 100
# hindujaglobalsolutions || hindujaglobalsolutionslimited || 100
# bharatpetroleumcorp || bharatpetroleumcorporationlimited || 100
# jktyres || jktyre&industrieslimited || 86
# bosch || boschlimited || 100
# deepakfertilizer || deepakfertilizersandpetrochemicalscorporationlimited || 100
# ratnamanimetals&tubes || ratnamanimetals&tubeslimited || 100
# l&tfinance || l&tfinanceholdingslimited || 100
# chambalfertilisers || chambalfertilizers&chemicalslimited || 94
# hathwaycable&datacom || hathwaycable&datacomlimited || 100
# edelweiss || edelweissfinancialserviceslimited || 100
# divi‘slaboratories || divi'slaboratorieslimited || 94
# kwality || kwalitylimited || 100
# mrf || mrflimited || 100
# drlalpathlabs || drlalpathlabsltd || 100
# cholamandalamfinance || cholamandalamfinancialholdingslimited || 95
# zensartech || zensartechnologieslimited || 100
# amararaja || amararajabatterieslimited || 100
# mahindrafinancial || mahindra&mahindrafinancialserviceslimited || 100
# tvsmotor || tvsmotorcompanylimited || 100
# navinfluorine || navinfluorineinternationallimited || 100
# sterlitetech || sterlitetechnologieslimited || 100
# nandandenim || nandandenimlimited || 100
# tubeinvestments || tubeinvestmentsofindialimited || 100
# jkumarinfra || jkumarinfraprojectslimited || 100
# powermechprojects || powermechprojectslimited || 100
# prestigeestatesprojects || prestigeestatesprojectslimited || 100
# sjvn || sjvnlimited || 100
# tv18broadcastltd || tv18broadcastlimited || 88
# schneiderelectric || schneiderelectricinfrastructurelimited || 100
# phillipscarbon || phillipscarbonblacklimited || 100
# sangamindia || sangamindialimited || 100
# gujratstatepetronet || gujaratstatepetronetlimited || 95
# sitinetworks || sitinetworkslimited || 100
# thyrocaretech || thyrocaretechnologieslimited || 100
# talbrosautomotive || talbrosautomotivecomponentslimited || 100
# elgiequipments || elgiequipmentslimited || 100
# salzerelectronics || salzerelectronicslimited || 100
# ufomoviez || ufomoviezindialimited || 100
# indianoilcorp || indianoilcorporationlimited || 100
# lgbalakrishnan || lgbalakrishnan&broslimited || 100
# navinflourine || navinfluorineinternationallimited || 92
# alembicpharmaceuticals || alembicpharmaceuticalslimited || 100
# jktyre || jktyre&industrieslimited || 100
# indianhumepipe || indianhumepipecompanylimited || 100
# tvssrichakra || tvssrichakralimited || 100
# infibeam || infibeamavenueslimited || 100
# takesolutions || takesolutionslimited || 100
# bharatpetroleum || bharatpetroleumcorporationlimited || 100
# neulandlaboratories || neulandlaboratorieslimited || 100
# dcmshriram || dcmshriramlimited || 100
# uflex || uflexlimited || 100
# vivimedlabs || vivimedlabslimited || 100
# adanipower || adanipowerlimited || 100
# eidparryindia || eidparryindialimited || 100
# lakshmimachineworks || lakshmimachineworkslimited || 100
# pricol || pricollimited || 100
# unichemlaboratories || unichemlaboratorieslimited || 100
# exideinds || exideindustrieslimited || 89
# ultratech || ultratechcementlimited || 100
# aartiinds || aartiindustrieslimited || 89
# igarashi || igarashimotorsindialimited || 100
# jubilantlife || jubilantlifescienceslimited || 100
# teamlease || teamleaseserviceslimited || 100
# kecintl || kecinternationallimited || 86
# banco || bancoproductslimited || 100
# manpasand || manpasandbeverageslimited || 100
# idbibank || idbibanklimited || 100
# nitinspinnersltd || nitinspinnerslimited || 88
# vsttillers || vsttillerstractorslimited || 100
# genuspowerinfra || genuspowerinfrastructureslimited || 100
# jkumarinfra || jkumarinfraprojectslimited || 100
# gmbreweriesltd || gmbrewerieslimited || 86
# tvsmotorcompanyltd || tvsmotorcompanylimited || 89
# powermechprojectsltd || powermechprojectslimited || 90
# srikalahasthipipes || srikalahasthipipeslimited || 100
# zuariagro || zuariagrochemicalslimited || 100
# jkumar || jkumarinfraprojectslimited || 100
# huhtamakippl || huhtamakippllimited || 100
# pidilite || pidiliteindustrieslimited || 100
# pidiliteind || pidiliteindustrieslimited || 100
# zeeentertain || zeeentertainmententerpriseslimited || 100
# repcohome || repcohomefinancelimited || 100
# ptcindiafin || ptcindiafinancialserviceslimited || 100
# irbinfra || irbinfrastructuredeveloperslimited || 100
# cosmofilms || cosmofilmslimited || 100
# indocount || indocountindustrieslimited || 100
# rppinfraproj || rppinfraprojectslimited || 100
# carborundum || carborundumuniversallimited || 100
# vguardind || vguardindustrieslimited || 100
# shriramtrans || shriramtransportfinancecompanylimited || 100
# sadbhavengg || sadbhavengineeringlimited || 91
# lakshmivilas || lakshmivilasbanklimited || 100
# kajariaceramic || kajariaceramicslimited || 100
# shriramcity || shriramcityunionfinancelimited || 100
# dredgingcorp || dredgingcorporationofindialimited || 100
# himatsingkasei || himatsingkaseidelimited || 100
# gmbreweries || gmbrewerieslimited || 100
# heidelbergcem || heidelbergcementindialimited || 100
# grasim || grasimindustrieslimited || 100
# knrconstruct || knrconstructionslimited || 100
# akzonobel || akzonobelindialimited || 100
# insecticides || insecticidesindialimited || 100
# bharatelec || bharatelectronicslimited || 100
# unichemlabs || unichemlaboratorieslimited || 91
# manappuramfin || manappuramfinancelimited || 100
# firstsourcesol || firstsourcesolutionslimited || 100
# divislabs || divi'slaboratorieslimited || 89
# astralpolytec || astralpolytechniklimited || 100
# cromptongreave || cromptongreavesconsumerelectricalslimited || 100
# sandesh || thesandeshlimited || 100
# voltamptrans || voltamptransformerslimited || 100
# wabco || wabcoindialimited || 100
# indianippon || indianipponelectricalslimited || 100
# simplexinfra || simplexinfrastructureslimited || 100
# aplapollo; || aplapollotubeslimited || 90
# ranemadras || ranemadraslimited || 100
# syngene; || syngeneinternationallimited || 88
# tatacomm; || tatacommunicationslimited || 89
# ultratechcement; || ultratechcementlimited || 94
# heritagefoods; || heritagefoodslimited || 93
# kalpatarupower; || kalpatarupowertransmissionlimited || 93
# timken; || timkenindialimited || 86
# lgbalakrishnan; || lgbalakrishnan&broslimited || 93
# ultratechcement; || ultratechcementlimited || 94
# itdcementation; || itdcementationindialimited || 93
# navabharatven; || navabharatventureslimited || 93
# cityunionbank; || cityunionbanklimited || 93
# godrejind; || godrejindustrieslimited || 90
# ambujacements; || ambujacementslimited || 93
# balkrishnaindustriesltd || balkrishnaindustrieslimited || 91
# ifbagro; || ifbagroindustrieslimited || 88
# escorts; || escortslimited || 88
# gulfoillubric; || gulfoillubricantsindialimited || 93
# aartiind; || aartiindustrieslimited || 89
# mahindracie; || mahindracieautomotivelimited || 92
# mindaind; || mindaindustrieslimited || 89
# voltas; || voltaslimited || 86
# apollohospitals; || apollohospitalsenterpriselimited || 94
# maxindia; || maxindialimited || 89
# oilindia; || oilindialimited || 89
# talbrosauto; || talbrosautomotivecomponentslimited || 92
# jkumar || jkumarinfraprojectslimited || 100
# mothersonsumisystemsltd || mothersonsumisystemslimited || 91
# phoenixmills; || thephoenixmillslimited || 92
# insecticidesindialtd || insecticidesindialimited || 90
# wonderla; || wonderlaholidayslimited || 89
# nestleindialtd || nestleindialimited || 86
# capitaltrust || capitaltrustlimited || 100
# tatacomm || tatacommunicationslimited || 100
# exideindustriesltd || exideindustrieslimited || 89
# cummins || cumminsindialimited || 100
# igarashimotorsltd || igarashimotorsindialimited || 88
# navkarcorp; || navkarcorporationlimited || 91
# bata || bataindialimited || 100
# mayuruniquoter; || mayuruniquotersltd || 93
# aurobindopharma; || aurobindopharmalimited || 94
# amrutanjanhealthcare || amrutanjanhealthcarelimited || 100
# drreddyslabs || drreddy'slaboratorieslimited || 92
# sterlitetechno || sterlitetechnologieslimited || 100
# suprajiteng || suprajitengineeringlimited || 100
# hexawaretech || hexawaretechnologieslimited || 100
# gujaratpipavav || gujaratpipavavportlimited || 100
# siyaramsilk || siyaramsilkmillslimited || 100
# glenmarkpharmaceuticals; || glenmarkpharmaceuticalslimited || 96
# jagranprakashan || jagranprakashanlimited || 100
# firstsource || firstsourcesolutionslimited || 100
# cholamandalaminvestment&finance; || cholamandalaminvestmentandfinancecompanylimited || 91
# eclerx || eclerxserviceslimited || 100
# montecarlo || montecarlofashionslimited || 100
# titan || titancompanylimited || 100
# centuryplyboard || centuryplyboardsindialimited || 100
# containercorp || containercorporationofindialimited || 100
# persistent || persistentsystemslimited || 100
# reliancecomm || reliancecommunicationslimited || 100
# spicejet || spicejetltd || 100
# interglobeavi || interglobeaviationlimited || 100
# chambalfert || chambalfertilizers&chemicalslimited || 100
# kotakmahindra || kotakmahindrabanklimited || 100
# triveniturbines || triveniturbinelimited || 93
# cignititech || cignititechnologieslimited || 100
# relainceindustries || relianceindustrieslimited || 94
# seshasayeepape || seshasayeepaperandboardslimited || 100
# sutlejtextiles || sutlejtextilesandindustrieslimited || 100
# kesarterminals || kesarterminals&infrastructurelimited || 100
# lincolnpharma || lincolnpharmaceuticalslimited || 100
# moldtekpack || moldtekpackaginglimited || 100
# kddl || kddllimited || 100
# sangam || sangamindialimited || 100

# %%
dfinal = pd.DataFrame({'recoName':ilist, 'formalName':matchlist})

# %%
dNotFound = pd.DataFrame({'recoName':iNotFoundList})

# %%
tot = y+z
tot
# Out:
# 1174

# %%
df3=df

# %%
stripped3 = []
for i in df3['NAME OF COMPANY'] :
    i = i.lower()
    i = i.replace(" ","")
    i = i.replace(".","")
    i = i.replace("(i)","")
    i = i.replace("(","")
    i = i.replace(")","")
    i = i.replace("-","")
    stripped3.append(i)
df3['formalName'] = stripped3

# %%
del df3['NAME OF COMPANY']
df3
# Out:
#           SYMBOL  SERIES   ISIN NUMBER                            formalName
# 0      20MICRONS      EQ  INE144J01027                      20micronslimited
# 1     21STCENMGM      EQ  INE253B01015  21stcenturymanagementserviceslimited
# 2     3IINFOTECH      EQ  INE748C01020                     3iinfotechlimited
# 3        3MINDIA      EQ  INE470A01017                        3mindialimited
# 4         3PLAND      EQ  INE105C01023                 3plandholdingslimited
# ...          ...     ...           ...                                   ...
# 1648   ZODJRDMKJ      EQ  INE077B01018                   zodiacjrdmkjlimited
# 1649        ZOTA      EQ  INE358U01012                 zotahealthcarelimited
# 1650       ZUARI      EQ  INE840M01016             zuariagrochemicalslimited
# 1651   ZUARIGLOB      EQ  INE217A01012                    zuarigloballimited
# 1652   ZYDUSWELL      EQ  INE768C01010                  zyduswellnesslimited
#
# [1653 rows x 4 columns]

# %%
dfinal = dfinal.merge(df3,on = 'formalName', how = 'inner')
dfinal
# Out:
#              recoName                            formalName      SYMBOL  \
# 0    siyaramsilkmills               siyaramsilkmillslimited      SIYSIL
# 1         siyaramsilk               siyaramsilkmillslimited      SIYSIL
# 2     jklakshmicement                jklakshmicementlimited   JKLAKSHMI
# 3    jklakshmicements                jklakshmicementlimited   JKLAKSHMI
# 4     jklakshmicement                jklakshmicementlimited   JKLAKSHMI
# ..                ...                                   ...         ...
# 831    seshasayeepape       seshasayeepaperandboardslimited  SESHAPAPER
# 832    sutlejtextiles    sutlejtextilesandindustrieslimited   SUTLEJTEX
# 833    kesarterminals  kesarterminals&infrastructurelimited        KTIL
# 834     lincolnpharma         lincolnpharmaceuticalslimited     LINCOLN
# 835              kddl                           kddllimited        KDDL
#
#      SERIES   ISIN NUMBER
# 0        EQ  INE076B01028
# 1        EQ  INE076B01028
# 2        EQ  INE786A01032
# 3        EQ  INE786A01032
# 4        EQ  INE786A01032
# ..      ...           ...
# 831      EQ  INE630A01024
# 832      EQ  INE645H01027
# 833      EQ  INE096L01025
# 834      EQ  INE405C01035
# 835      EQ  INE291D01011
#
# [836 rows x 5 columns]

# %%
del dfinal[' SERIES']
del dfinal[' ISIN NUMBER']
del dfinal['formalName']
dfinal
# Out:
#              recoName      SYMBOL
# 0    siyaramsilkmills      SIYSIL
# 1         siyaramsilk      SIYSIL
# 2     jklakshmicement   JKLAKSHMI
# 3    jklakshmicements   JKLAKSHMI
# 4     jklakshmicement   JKLAKSHMI
# ..                ...         ...
# 831    seshasayeepape  SESHAPAPER
# 832    sutlejtextiles   SUTLEJTEX
# 833    kesarterminals        KTIL
# 834     lincolnpharma     LINCOLN
# 835              kddl        KDDL
#
# [836 rows x 2 columns]

# %%
dfinal = dfinal.append(dNotFound, ignore_index = True, sort = False)
dfinal
# Out:
#               recoName     SYMBOL
# 0     siyaramsilkmills     SIYSIL
# 1          siyaramsilk     SIYSIL
# 2      jklakshmicement  JKLAKSHMI
# 3     jklakshmicements  JKLAKSHMI
# 4      jklakshmicement  JKLAKSHMI
# ...                ...        ...
# 1169     uplondeclines        NaN
# 1170  jetairwaysondips        NaN
# 1171    jenburktpharma        NaN
# 1172     samkrgpistons        NaN
# 1173              hdil        NaN
#
# [1174 rows x 2 columns]

# %%
dfinal.to_sql(con=database_connection, name='symbolsmappedMC', if_exists='append')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py:1336: UserWarning: The provided table name 'symbolsmappedMC' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
