# %%
import pandas as pd
import numpy as np

import mysql.connector
from sqlalchemy import create_engine
import pandas.io.sql as psql
import sqlalchemy

from dateutil import parser
from datetime import datetime
from datetime import date
from dateutil.relativedelta import relativedelta

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix

# %%
database_username = 'smarsproddbuser@mbt-smars-mysql'
database_password = 'modern@1234'
database_ip       = 'mbt-smars-mysql.mysql.database.azure.com'
database_name     = 'mainschema'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name))

# %%
df = pd.read_sql('SELECT * FROM mcbrokerperformance2018', con=database_connection)
del df['index']
df
# Out:
#                             Name  Hit Ratio  Avg. Growth  Total Recos
# 0                   ICICI Direct         47           24           92
# 1                         Geojit          0            0            1
# 2             Nalanda Securities         42            7           28
# 3                 SPA Securities        100            7            1
# 4                    Anand Rathi         47           13           38
# 5                        Bonanza         50           17            2
# 6                      Rupak De​        100           25            1
# 7               Kotak Securities         53          471           30
# 8                HDFC Securities         51          136          100
# 9       Cholamandalam Securities         44           34           29
# 10                    Arpan Shah         66           20            3
# 11                 Shitij Gandhi         38            2           13
# 12             Dalmia Securities         33            5            3
# 13                 Dolat Capital         45           11           22
# 14                 Motilal Oswal         45           23           86
# 15            Ashish Chaturmohta         36           11           19
# 16                  LKP Research         80           12            5
# 17           Prabhudas Lilladher         51           12           41
# 18                  Vinay Rajani         66            7            9
# 19               Shabbir Kayyumi         73           13           23
# 20                 Dharmesh Shah         28            0            7
# 21                       Centrum         39            8           38
# 22                      Rupak De         27            0           11
# 23                    KR Choksey         41          357           12
# 24  Rudra Shares & Stock Brokers         55           17            9
# 25                 Dinesh Rohira         66           13            6
# 26              Hadrien Mendonca         53          184           13
# 27               Aditya Agarwala          0            0            6
# 28               Abhishek Mondal         53          104           13
# 29                  JM Financial         36            7           33
# 30                     Sharekhan         33           25            6
# 31                    Akash Jain         20            0            5
# 32                Jayant Manglik         50           15            6
# 33      Cholamandalam securities        100           31            2
# 34                 Choice Equity        100            0            1
# 35               Mazhar Mohammad        100           16            3
# 36                 Sameet Chavan        100           24            1
# 37               Arihant Capital        100            0            2
# 38                Mustafa Nadeem         66            6            3
# 39                  Nandish Shah         50          539           12
# 40              Siddharth Sedani         40            1            5
# 41                 CD Equisearch         60           19            5
# 42                  Manav Chopra          0            0            3
# 43                Aditya Agarwal         33            4            3
# 44          Khambatta Securities        100           39            2
# 45                    AnandRathi         25            2            4
# 46                Rajesh Palviya         37            6            8
# 47      Joindre Capital Services        100           26            2
# 48                      Equity99         25            0            4
# 49                    AnantRathi        100            1            1
# 50                    Vikas Jain        100            6            2
# 51              Shailendra Kumar         25            0            4
# 52                  Axis Capital          0            0            1
# 53               Axis Securities        100           14            1
# 54               Prashanth Tapse         40           10            5
# 55              Centrum Research         33            5            3
# 56              Chola Securities         50           17            2
# 57                     KRChoksey         40           11            5

# %%
X1 = df[['Avg. Growth','Avg. Growth']]
model1 = KMeans(n_clusters=5).fit(X1)
centroids1 = model1.cluster_centers_
sortedcentroids1 = centroids1[:,0].copy()
sortedcentroids1.sort(axis=0)
labeldict1 = {}
for i in centroids1[:,0] :
    x = list(sortedcentroids1).index(i)
    y = list(centroids1[:,0]).index(i)
    labeldict1[y] = x
    unsortedlabels1 = model1.predict(X1)
sortedlabels1 = []
for element in unsortedlabels1 :
    sortedlabels1.append(labeldict1[element]+1)

plt.figure(figsize=(10,10))
plt.scatter(df['Avg. Growth'], df['Avg. Growth'], c= unsortedlabels1, s=25, alpha=0.5)
plt.scatter(centroids1[:, 0], centroids1[:, 1], c='red', s=50)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X2 = df[['Total Recos','Total Recos']]
model2 = KMeans(n_clusters=5).fit(X2)
centroids2 = model2.cluster_centers_
sortedcentroids2 = centroids2[:,0].copy()
sortedcentroids2.sort(axis=0)
labeldict2 = {}
for i in centroids2[:,0] :
    x = list(sortedcentroids2).index(i)
    y = list(centroids2[:,0]).index(i)
    labeldict2[y] = x
    unsortedlabels2 = model2.predict(X2)
sortedlabels2 = []
for element in unsortedlabels2 :
    sortedlabels2.append(labeldict2[element]+1)

plt.figure(figsize=(10,10))
plt.scatter(df['Total Recos'], df['Total Recos'], c= unsortedlabels2, s=25, alpha=0.5)
plt.scatter(centroids2[:, 0], centroids2[:, 1], c='red', s=50)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X3 = df[['Hit Ratio','Hit Ratio']]
model3 = KMeans(n_clusters=5).fit(X3)
centroids3 = model3.cluster_centers_
sortedcentroids3 = centroids3[:,0].copy()
sortedcentroids3.sort(axis=0)
labeldict3 = {}
for i in centroids3[:,0] :
    x = list(sortedcentroids3).index(i)
    y = list(centroids3[:,0]).index(i)
    labeldict3[y] = x
    unsortedlabels3 = model3.predict(X3)
sortedlabels3 = []
for element in unsortedlabels3 :
    sortedlabels3.append(labeldict3[element]+1)

plt.figure(figsize=(10,10))
plt.scatter(df['Hit Ratio'], df['Hit Ratio'], c= unsortedlabels3, s=25, alpha=0.5)
plt.scatter(centroids3[:, 0], centroids3[:, 1], c='red', s=50)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
dfanalysis = pd.DataFrame({'broker': df['Name'], 'Hit Ratio': sortedlabels3,'Avg. Growth' : sortedlabels1, 'Total Recos' : sortedlabels2})
dfanalysis
# Out:
#                           broker  Hit Ratio  Avg. Growth  Total Recos
# 0                   ICICI Direct          3            2            5
# 1                         Geojit          1            1            1
# 2             Nalanda Securities          3            1            3
# 3                 SPA Securities          5            1            1
# 4                    Anand Rathi          3            1            4
# 5                        Bonanza          3            2            1
# 6                      Rupak De​          5            2            1
# 7               Kotak Securities          3            5            3
# 8                HDFC Securities          3            3            5
# 9       Cholamandalam Securities          3            2            3
# 10                    Arpan Shah          4            2            1
# 11                 Shitij Gandhi          2            1            2
# 12             Dalmia Securities          2            1            1
# 13                 Dolat Capital          3            1            3
# 14                 Motilal Oswal          3            2            5
# 15            Ashish Chaturmohta          2            1            3
# 16                  LKP Research          4            1            1
# 17           Prabhudas Lilladher          3            1            4
# 18                  Vinay Rajani          4            1            2
# 19               Shabbir Kayyumi          4            1            3
# 20                 Dharmesh Shah          2            1            1
# 21                       Centrum          3            1            4
# 22                      Rupak De          2            1            2
# 23                    KR Choksey          3            4            2
# 24  Rudra Shares & Stock Brokers          3            2            2
# 25                 Dinesh Rohira          4            1            1
# 26              Hadrien Mendonca          3            3            2
# 27               Aditya Agarwala          1            1            1
# 28               Abhishek Mondal          3            3            2
# 29                  JM Financial          2            1            4
# 30                     Sharekhan          2            2            1
# 31                    Akash Jain          2            1            1
# 32                Jayant Manglik          3            2            1
# 33      Cholamandalam securities          5            2            1
# 34                 Choice Equity          5            1            1
# 35               Mazhar Mohammad          5            2            1
# 36                 Sameet Chavan          5            2            1
# 37               Arihant Capital          5            1            1
# 38                Mustafa Nadeem          4            1            1
# 39                  Nandish Shah          3            5            2
# 40              Siddharth Sedani          3            1            1
# 41                 CD Equisearch          4            2            1
# 42                  Manav Chopra          1            1            1
# 43                Aditya Agarwal          2            1            1
# 44          Khambatta Securities          5            2            1
# 45                    AnandRathi          2            1            1
# 46                Rajesh Palviya          2            1            2
# 47      Joindre Capital Services          5            2            1
# 48                      Equity99          2            1            1
# 49                    AnantRathi          5            1            1
# 50                    Vikas Jain          5            1            1
# 51              Shailendra Kumar          2            1            1
# 52                  Axis Capital          1            1            1
# 53               Axis Securities          5            2            1
# 54               Prashanth Tapse          3            1            1
# 55              Centrum Research          2            1            1
# 56              Chola Securities          3            2            1
# 57                     KRChoksey          3            1            1

# %%
dictstar1 = {1:1,   2:0.8, 3:0.6, 4:0.4, 5:0 }
dictstar2 = {1:0.8, 2:1,   3:0.8, 4:0.6, 5:0.4 }
dictstar3 = {1:0.6, 2:0.8, 3:1,   4:0.8, 5:0.6 }
dictstar4 = {1:0.4, 2:0.6, 3:0.8, 4:1,   5:0.6 }
dictstar5 = {1:0.2, 2:0.4, 3:0.6, 4:0.8, 5:1 }

# %%
star = []
for index, row in dfanalysis.iterrows():
    hr = row['Hit Ratio']
    ag = row['Avg. Growth']
    tr = row['Total Recos']
    probabilities = []
    probabilities.append(dictstar1[hr]*dictstar1[ag]*dictstar1[tr]) 
    probabilities.append(dictstar2[hr]*dictstar2[ag]*dictstar2[tr]) 
    probabilities.append(dictstar3[hr]*dictstar3[ag]*dictstar3[tr]) 
    probabilities.append(dictstar4[hr]*dictstar4[ag]*dictstar4[tr]) 
    probabilities.append(dictstar5[hr]*dictstar5[ag]*dictstar5[tr]) 
    rating = probabilities.index(max(probabilities))+1
    star.append(rating)

# %%
dfanalysis['Rating'] = star
dfanalysis
# Out:
#                           broker  Hit Ratio  Avg. Growth  Total Recos  Rating
# 0                   ICICI Direct          3            2            5       3
# 1                         Geojit          1            1            1       1
# 2             Nalanda Securities          3            1            3       3
# 3                 SPA Securities          5            1            1       2
# 4                    Anand Rathi          3            1            4       3
# 5                        Bonanza          3            2            1       2
# 6                      Rupak De​          5            2            1       2
# 7               Kotak Securities          3            5            3       3
# 8                HDFC Securities          3            3            5       3
# 9       Cholamandalam Securities          3            2            3       3
# 10                    Arpan Shah          4            2            1       2
# 11                 Shitij Gandhi          2            1            2       2
# 12             Dalmia Securities          2            1            1       1
# 13                 Dolat Capital          3            1            3       3
# 14                 Motilal Oswal          3            2            5       3
# 15            Ashish Chaturmohta          2            1            3       2
# 16                  LKP Research          4            1            1       1
# 17           Prabhudas Lilladher          3            1            4       3
# 18                  Vinay Rajani          4            1            2       2
# 19               Shabbir Kayyumi          4            1            3       3
# 20                 Dharmesh Shah          2            1            1       1
# 21                       Centrum          3            1            4       3
# 22                      Rupak De          2            1            2       2
# 23                    KR Choksey          3            4            2       3
# 24  Rudra Shares & Stock Brokers          3            2            2       2
# 25                 Dinesh Rohira          4            1            1       1
# 26              Hadrien Mendonca          3            3            2       3
# 27               Aditya Agarwala          1            1            1       1
# 28               Abhishek Mondal          3            3            2       3
# 29                  JM Financial          2            1            4       2
# 30                     Sharekhan          2            2            1       2
# 31                    Akash Jain          2            1            1       1
# 32                Jayant Manglik          3            2            1       2
# 33      Cholamandalam securities          5            2            1       2
# 34                 Choice Equity          5            1            1       2
# 35               Mazhar Mohammad          5            2            1       2
# 36                 Sameet Chavan          5            2            1       2
# 37               Arihant Capital          5            1            1       2
# 38                Mustafa Nadeem          4            1            1       1
# 39                  Nandish Shah          3            5            2       3
# 40              Siddharth Sedani          3            1            1       1
# 41                 CD Equisearch          4            2            1       2
# 42                  Manav Chopra          1            1            1       1
# 43                Aditya Agarwal          2            1            1       1
# 44          Khambatta Securities          5            2            1       2
# 45                    AnandRathi          2            1            1       1
# 46                Rajesh Palviya          2            1            2       2
# 47      Joindre Capital Services          5            2            1       2
# 48                      Equity99          2            1            1       1
# 49                    AnantRathi          5            1            1       2
# 50                    Vikas Jain          5            1            1       2
# 51              Shailendra Kumar          2            1            1       1
# 52                  Axis Capital          1            1            1       1
# 53               Axis Securities          5            2            1       2
# 54               Prashanth Tapse          3            1            1       1
# 55              Centrum Research          2            1            1       1
# 56              Chola Securities          3            2            1       2
# 57                     KRChoksey          3            1            1       1

# %%
dfanalysis.to_sql(con=database_connection, name='mcfinalrating2018', if_exists='replace')

# %%
df2016 = pd.read_sql('SELECT * FROM mcfinalrating2016', con=database_connection)
del df2016['index']
df2016
# Out:
#                   broker  Hit Ratio  Avg. Growth  Total Recos  Rating
# 0          Motilal Oswal          2            2            5       2
# 1        Arihant Capital          3            2            1       2
# 2        ICICI Securties          1            1            1       1
# 3            AUM Capital          5            3            1       3
# 4              Edelweiss          3            2            5       3
# ..                   ...        ...          ...          ...     ...
# 89  Khambatta securities          3            3            1       3
# 90       Shubham Agarwal          3            1            1       1
# 91        Mayuresh Joshi          5            3            1       3
# 92          Simi Bhaumik          5            2            1       2
# 93          Bhavin Desai          5            3            1       3
#
# [94 rows x 5 columns]

# %%
df2017 = pd.read_sql('SELECT * FROM finalrating2017', con=database_connection)
del df2017['index']
df2017
# Out:
#                   broker  Hit Ratio  Avg. Growth  Total Recos  Rating
# 0    Indiabulls Ventures          2            3            1       2
# 1    Indiabulls Ventures          2            3            1       2
# 2          Motilal Oswal          3            4            5       3
# 3                Ventura          2            2            1       2
# 4        ICICIdirect.com          4            5            5       5
# ..                   ...        ...          ...          ...     ...
# 56          India Nivesh          2            1            1       1
# 57        Sushil Finance          5            3            1       3
# 58    Wallfort Financial          1            1            1       1
# 59          GEPL Capital          3            2            1       2
# 60  Ashika Stock Broking          1            1            1       1
#
# [61 rows x 5 columns]

# %%
df201617 = pd.concat([df2016, df2017], ignore_index=True)
df201617
# Out:
#                    broker  Hit Ratio  Avg. Growth  Total Recos  Rating
# 0           Motilal Oswal          2            2            5       2
# 1         Arihant Capital          3            2            1       2
# 2         ICICI Securties          1            1            1       1
# 3             AUM Capital          5            3            1       3
# 4               Edelweiss          3            2            5       3
# ..                    ...        ...          ...          ...     ...
# 150          India Nivesh          2            1            1       1
# 151        Sushil Finance          5            3            1       3
# 152    Wallfort Financial          1            1            1       1
# 153          GEPL Capital          3            2            1       2
# 154  Ashika Stock Broking          1            1            1       1
#
# [155 rows x 5 columns]

# %%
Xtrain = df201617[['Hit Ratio','Avg. Growth','Total Recos']].values
Ytrain = df201617['Rating'].values
Xtest = dfanalysis[['Hit Ratio','Avg. Growth','Total Recos']].values

# %%
clf = GaussianNB()
clf.fit(Xtrain, Ytrain)
GaussianNB()
Ytest = clf.predict(Xtest)

# %%
score = clf.score(Xtest,dfanalysis['Rating'].values)
score
# Out:
# 0.7758620689655172

# %%
confusion_matrix(dfanalysis['Rating'],Ytest)
# Out:
# array([[18,  0,  0,  0],
#        [ 5, 14,  6,  0],
#        [ 0,  1, 13,  1],
#        [ 0,  0,  0,  0]], dtype=int64)
