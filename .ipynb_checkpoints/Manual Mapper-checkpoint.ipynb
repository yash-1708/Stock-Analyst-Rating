# %%
import pandas as pd

from dateutil import parser
from datetime import datetime
from dateutil.relativedelta import relativedelta

import mysql.connector
from sqlalchemy import create_engine
import pandas.io.sql as psql
import sqlalchemy

# %%
database_username = 'root'
database_password = 'yash'
database_ip       = '127.0.0.1'
database_name     = 'mainschema'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name))

# %%
df = pd.read_sql('SELECT * FROM notmapped', con=database_connection)

# %%
df
# Out:
#      index            recoName SYMBOL
# 0      565       larsen&toubro   None
# 1      566  sahyadriindustries   None
# 2      567         sanofiindia   None
# 3      568                 itc   None
# 4      569            axisbank   None
# 5      570               emami   None
# 6      571                hdfc   None
# 7      572                 tcs   None
# 8      573            jkcement   None
# 9      574  greenplyindustries   None
# 10     575     knrconstruction   None
# 11     576    shankarabldgprod   None
# 12     577                cesc   None
# 13     578    bajajhold&invest   None
# 14     579                ongc   None
# 15     580    ipcalaboratories   None
# 16     581     lumaxindustries   None
# 17     582            oilindia   None
# 18     583    safariindustries   None
# 19     584                 acc   None
# 20     585           coalindia   None
# 21     586      aiaengineering   None
# 22     587      engineersindia   None
# 23     588       sunpharmainds   None
# 24     589  hginfraengineering   None
# 25     590   dixontechnologies   None
# 26     591         jindalhisar   None
# 27     592      aparindustries   None
# 28     593             ltfoods   None
# 29     594                niit   None
# ..     ...                 ...    ...
# 192    757         bandhanbank   None
# 193    758    bhansalienggpoly   None
# 194    759       primaplastics   None
# 195    760    dollarindustries   None
# 196    761      tvselectronics   None
# 197    762    blsinternatlserv   None
# 198    763    rppinfraprojects   None
# 199    764             nelcast   None
# 200    765         ultramarine   None
# 201    766           shalbyltd   None
# 202    767    simmondsmarshall   None
# 203    768                gnfc   None
# 204    769         nglfinechem   None
# 205    770     kritiindustries   None
# 206    771     mircelectronics   None
# 207    772    elantasbeckindia   None
# 208    773    veerenergy&infra   None
# 209    774    masfinancialserv   None
# 210    775         arcotechltd   None
# 211    776                 hil   None
# 212    777  nationalplasticind   None
# 213    778  kovaimedicalcenter   None
# 214    779    ganeshbenzoplast   None
# 215    780      iolchem&pharma   None
# 216    781       eonelectronic   None
# 217    782                wpil   None
# 218    783    rajshreepolypack   None
# 219    784    safariindustries   None
# 220    785              nirlon   None
# 221    786     hdfcassetmngtco   None
#
# [222 rows x 3 columns]

# %%
del df['index']
df
# Out:
#                recoName SYMBOL
# 0         larsen&toubro   None
# 1    sahyadriindustries   None
# 2           sanofiindia   None
# 3                   itc   None
# 4              axisbank   None
# 5                 emami   None
# 6                  hdfc   None
# 7                   tcs   None
# 8              jkcement   None
# 9    greenplyindustries   None
# 10      knrconstruction   None
# 11     shankarabldgprod   None
# 12                 cesc   None
# 13     bajajhold&invest   None
# 14                 ongc   None
# 15     ipcalaboratories   None
# 16      lumaxindustries   None
# 17             oilindia   None
# 18     safariindustries   None
# 19                  acc   None
# 20            coalindia   None
# 21       aiaengineering   None
# 22       engineersindia   None
# 23        sunpharmainds   None
# 24   hginfraengineering   None
# 25    dixontechnologies   None
# 26          jindalhisar   None
# 27       aparindustries   None
# 28              ltfoods   None
# 29                 niit   None
# ..                  ...    ...
# 192         bandhanbank   None
# 193    bhansalienggpoly   None
# 194       primaplastics   None
# 195    dollarindustries   None
# 196      tvselectronics   None
# 197    blsinternatlserv   None
# 198    rppinfraprojects   None
# 199             nelcast   None
# 200         ultramarine   None
# 201           shalbyltd   None
# 202    simmondsmarshall   None
# 203                gnfc   None
# 204         nglfinechem   None
# 205     kritiindustries   None
# 206     mircelectronics   None
# 207    elantasbeckindia   None
# 208    veerenergy&infra   None
# 209    masfinancialserv   None
# 210         arcotechltd   None
# 211                 hil   None
# 212  nationalplasticind   None
# 213  kovaimedicalcenter   None
# 214    ganeshbenzoplast   None
# 215      iolchem&pharma   None
# 216       eonelectronic   None
# 217                wpil   None
# 218    rajshreepolypack   None
# 219    safariindustries   None
# 220              nirlon   None
# 221     hdfcassetmngtco   None
#
# [222 rows x 2 columns]

# %%
for i in df['recoName']:
    print(i)
    print('Do you wish to enter the nse symmol: ')
    choise = input() 
    if choice == 'y' || choice == 'Y':
        print('Enter the NSE symbol: ')
        symbol = input()
        #append in db
# Out:
# larsen&toubro
# Do you wish to enter the nse symmol:
# i
# sahyadriindustries
# Do you wish to enter the nse symmol:
