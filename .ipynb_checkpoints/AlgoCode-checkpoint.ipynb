# %%
import pandas as pd
import numpy as np

import mysql.connector
from sqlalchemy import create_engine
import pandas.io.sql as psql
import sqlalchemy

from dateutil import parser
from datetime import datetime
from datetime import date
from dateutil.relativedelta import relativedelta

# %%
database_username = 'root'
database_password = 'yash'
database_ip       = '127.0.0.1'
database_name     = 'mainschema'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name))

# %%
df = pd.read_sql('SELECT * FROM marketsmojorecos', con=database_connection)

# %%
start_date = '2016-01-01'
end_date = '2016-12-31'
date_object1 = datetime.strptime(start_date, '%Y-%m-%d').date()
date_object2 = datetime.strptime(end_date, '%Y-%m-%d').date()

# %%
mask = (df['predict_date'] > date_object1) & (df['predict_date'] <= date_object2)

# %% [markdown]
# # 2016 data

# %%
df1 = df.loc[mask]
df1 = df1.reset_index()
del df1['level_0']
del df1['srno']
del df1['index']

# %%
print("No of Brokers in 2016 :",df1['broker'].nunique()) 
s1=len(df1)
# Out:
# No of Brokers in 2016 : 61

# %%
df3=pd.DataFrame()
for i in range(0,5198): 
    sym=df1.at[i, 'company_name']
    sym = sym.lower()
    sym = sym.replace(" ","")
    sym = sym.replace(".","")
    sym = sym.replace("(i)","")
    sym = sym.replace("(","")
    sym = sym.replace(")","")
    sym = sym.replace("-","")
    sqlrun = "SELECT SYMBOL FROM symbolsmapped WHERE recoName = '"+sym+"'"
    df3 = df3.append(pd.read_sql(sqlrun, con=database_connection),ignore_index=True)

# %%
df4 =pd.concat([df1,df3],axis=1)
df4
# Out:
#                  broker          company_name  current_price  \
# 0             KRChoksey          Force Motors        1199.90
# 1           AUM Capital   Narayana Hrudayalay         239.00
# 2              Religare            ICICI Bank         390.15
# 3     Enochventures.com      Parag Milk Foods         137.65
# 4             Edelweiss  Kewal Kiran Clothing        1000.00
# ...                 ...                   ...            ...
# 5193        Axis Direct     Cox & Kings India           3.61
# 5194      Dolat Capital               Mphasis         966.20
# 5195      Angel Broking  Dewan Hsg Fin. Corp.          47.15
# 5196      Angel Broking   MBL Infrastructures           5.57
# 5197    ICICIdirect.com         Ultratech Cem        3883.75
#
#      recomended_buying predict_date target_price      SYMBOL
# 0              3497.00   2016-10-03      4820.00    FORCEMOT
# 1               325.55   2016-09-27       400.00          NH
# 2               217.73   2016-08-04       181.82   ICICIBANK
# 3                329.6   2016-07-12       425.00   PARAGMILK
# 4              1796.00   2016-05-25      2039.00        KKCL
# ...                ...          ...          ...         ...
# 5193            179.00   2016-04-06       338.00       CKFSL
# 5194            454.00   2016-04-05       620.00     MPHASIS
# 5195            189.00   2016-04-05       270.00        DHFL
# 5196            154.00   2016-04-04       285.00    MBLINFRA
# 5197           3237.00   2016-04-01      3600.00  ULTRACEMCO
#
# [5198 rows x 7 columns]

# %%
uniqueBrokers = df4.broker.unique()

# %%
for brokerName in uniqueBrokers :
    dfbrokerRecos = df4.loc[df4['broker'] == brokerName]
    print('brokerName : ',brokerName)
    for index, row in dfbrokerRecos.iterrows():
        #print(row)
        sym = row['SYMBOL']
        if type(sym) == str :
            mydate1 = row['predict_date']#prediction date
            mydate2 = mydate1 + relativedelta(years=1)#date 1 year after prediction
            dbyear1 = "nse"+str(mydate1.year)
            dbyear2 = "nse"+str(mydate2.year)
        
            sqlrun1 = "SELECT * FROM "+dbyear1+" WHERE Date >= '"+str(mydate1)+"' AND Symbol = '"+sym+"'"
            dfprices1 = pd.read_sql(sqlrun1, con=database_connection)
            del dfprices1['index']
        
            sqlrun2 = "SELECT * FROM "+dbyear2+" WHERE Date <= '"+str(mydate2)+"' AND Symbol = '"+sym+"'"
            dfprices2 = pd.read_sql(sqlrun2, con=database_connection)
            del dfprices2['index']
            dfprices = pd.concat([dfprices1,dfprices2],ignore_index=True)

            targetp = float(row['target_price'])
        
            print("SYMBOL : ",sym)
            dfhits = dfprices.loc[dfprices['Closeval'] >= targetp]
        
            if dfhits.empty :
                print("hit : 0")
            else :
                print("hit : 1")
            
            recbuying = float(row['recomended_buying'])
            maxval = dfprices['Closeval'].max()
            growthperc = (maxval - recbuying) *100 / recbuying
            print('Growth : ',growthperc)
# Out:
# brokerName :  KRChoksey
# SYMBOL :  FORCEMOT
# hit : 0
# Growth :  nan
# SYMBOL :  FORCEMOT
# hit : 0
# Growth :  nan
# SYMBOL :  FORCEMOT
# hit : 0
# Growth :  nan
# SYMBOL :  SOLARINDS
# hit : 1
# Growth :  80.4476479514416
# SYMBOL :  BAJFINANCE
# hit : 1
# Growth :  130.15240328253225
# SYMBOL :  INFIBEAM
# hit : 1
# Growth :  31.394101876675595
# SYMBOL :  TV18BRDCST
# hit : 0
# Growth :  50.92105263157895
# SYMBOL :  STRTECH
# hit : 1
# Growth :  212.4468085106383
# SYMBOL :  SCHNEIDER
# hit : 0
# Growth :  11.478873239436627
# SYMBOL :  BALKRISIND
# hit : 1
# Growth :  81.16484440706478
# SYMBOL :  TATAMOTORS
# hit : 0
# Growth :  18.552915766738657
# SYMBOL :  INFIBEAM
# hit : 1
# Growth :  40.69856459330143
# SYMBOL :  EMMBI
# hit : 1
# Growth :  115.56521739130434
# SYMBOL :  IGL
# hit : 1
# Growth :  860.6547619047619
# SYMBOL :  PETRONET
# hit : 1
# Growth :  159.74063400576367
# SYMBOL :  MONTECARLO
# hit : 1
# Growth :  42.074592074592076
# SYMBOL :  MINDAIND
# hit : 1
# Growth :  205.16176470588235
# SYMBOL :  BANKBARODA
# hit : 1
# Growth :  21.58385093167702
# SYMBOL :  SBIN
# hit : 0
# Growth :  22.179487179487182
# SYMBOL :  MANAPPURAM
# hit : 0
# Growth :  12.5
# SYMBOL :  SUNPHARMA
# hit : 0
# Growth :  8.170914542728635
# SYMBOL :  BHARATFORG
# hit : 1
# Growth :  199.96470588235292
# SYMBOL :  ICICIBANK
# hit : 1
# Growth :  33.988671810868496
# SYMBOL :  BRITANNIA
# hit : 1
# Growth :  52.20569417786307
# SYMBOL :  UNIONBANK
# hit : 1
# Growth :  42.16417910447761
# SYMBOL :  PNB
# hit : 1
# Growth :  52.57142857142856
# SYMBOL :  CHOLAFIN
# hit : 0
# Growth :  9.114035087719307
# SYMBOL :  UPL
# hit : 1
# Growth :  30.145560407569146
# SYMBOL :  BAJFINANCE
# hit : 1
# Growth :  81.60962072155412
# SYMBOL :  NESTLEIND
# hit : 0
# Growth :  6.4201353881607375
# SYMBOL :  BAJAJ-AUTO
# hit : 1
# Growth :  16.161562829989442
# SYMBOL :  BAJAJFINSV
# hit : 1
# Growth :  65.79814921920186
# SYMBOL :  MARUTI
# hit : 1
# Growth :  39.23621778460489
# SYMBOL :  STRTECH
# hit : 1
# Growth :  156.7452830188679
# SYMBOL :  CANBK
# hit : 1
# Growth :  41.90322580645161
# SYMBOL :  HINDUNILVR
# hit : 1
# Growth :  52.274346793349174
# SYMBOL :  GRANULES
# hit : 0
# Growth :  21.640000000000008
# SYMBOL :  AXISBANK
# hit : 0
# Growth :  11.899383983572905
# SYMBOL :  UNICHEMLAB
# hit : 0
# Growth :  1.154575219713949
# SYMBOL :  DRREDDY
# hit : 0
# Growth :  5.093033792122983
# SYMBOL :  HDFCBANK
# hit : 1
# Growth :  50.685483870967744
# SYMBOL :  APLLTD
# hit : 0
# Growth :  -0.3392330383480759
# SYMBOL :  KOTAKBANK
# hit : 1
# Growth :  33.64634146341464
# SYMBOL :  ITC
# hit : 1
# Growth :  43.455497382198956
# SYMBOL :  RELIANCE
# hit : 1
# Growth :  210.0526118000751
# SYMBOL :  HCLTECH
# hit : 1
# Growth :  12.779014499729263
# SYMBOL :  WIPRO
# hit : 1
# Growth :  124.57932692307689
# SYMBOL :  YESBANK
# hit : 1
# Growth :  613.754223453931
# SYMBOL :  STRTECH
# hit : 1
# Growth :  164.22330097087374
# SYMBOL :  TCS
# hit : 1
# Growth :  12.333333333333334
# SYMBOL :  INFY
# hit : 0
# Growth :  0.6501975711787626
# SYMBOL :  TV18BRDCST
# hit : 0
# Growth :  4.462242562929052
# SYMBOL :  INDUSINDBK
# hit : 1
# Growth :  47.67106347897774
# SYMBOL :  AARTIIND
# hit : 1
# Growth :  46.06351550960119
# SYMBOL :  INFIBEAM
# hit : 1
# Growth :  55.25871172122491
# SYMBOL :  KWALITY
# hit : 0
# Growth :  33.30645161290323
# SYMBOL :  GSPL
# hit : 1
# Growth :  34.17508417508417
# SYMBOL :  PETRONET
# hit : 1
# Growth :  156.05113636363635
# SYMBOL :  MRPL
# hit : 1
# Growth :  70.1829268292683
# SYMBOL :  CHENNPETRO
# hit : 1
# Growth :  59.44636678200692
# SYMBOL :  INOXWIND
# hit : 0
# Growth :  32.83625730994152
# SYMBOL :  UFLEX
# hit : 0
# Growth :  72.72200772200773
# SYMBOL :  CIPLA
# hit : 0
# Growth :  15.82386363636363
# SYMBOL :  EMMBI
# hit : 1
# Growth :  72.26890756302521
# SYMBOL :  HEROMOTOCO
# hit : 1
# Growth :  14.483506944444448
# SYMBOL :  INDUSINDBK
# hit : 1
# Growth :  37.970253718285214
# SYMBOL :  CKFSL
# hit : 0
# Growth :  nan
# SYMBOL :  NHPC
# hit : 0
# Growth :  -55.50182958703607
# SYMBOL :  MINDAIND
# hit : 1
# Growth :  581.427955133736
# SYMBOL :  ONGC
# hit : 1
# Growth :  118.68647928786712
# SYMBOL :  GAIL
# hit : 1
# Growth :  82.27593152064449
# SYMBOL :  CIPLA
# hit : 0
# Growth :  30.673076923076916
# SYMBOL :  UNICHEMLAB
# hit : 0
# Growth :  17.500000000000004
# SYMBOL :  RELIANCE
# hit : 1
# Growth :  41.86390532544379
# SYMBOL :  HDFCBANK
# hit : 1
# Growth :  40.49817184643509
# SYMBOL :  INDUSINDBK
# hit : 1
# Growth :  46.70918367346939
# SYMBOL :  SOLARINDS
# hit : 1
# Growth :  80.4476479514416
# SYMBOL :  BAJFINANCE
# hit : 1
# Growth :  130.15240328253225
# SYMBOL :  TV18BRDCST
# hit : 0
# Growth :  50.92105263157895
# SYMBOL :  INFIBEAM
# hit : 1
# Growth :  31.394101876675595
# SYMBOL :  STRTECH
# hit : 1
# Growth :  212.4468085106383
# SYMBOL :  SCHNEIDER
# hit : 0
# Growth :  11.478873239436627
# SYMBOL :  BALKRISIND
# hit : 1
# Growth :  81.16484440706478
# SYMBOL :  TATAMOTORS
# hit : 0
# Growth :  18.552915766738657
# SYMBOL :  INFIBEAM
# hit : 1
# Growth :  40.69856459330143
# SYMBOL :  IGL
# hit : 1
# Growth :  860.6547619047619
# SYMBOL :  EMMBI
# hit : 1
# Growth :  115.56521739130434
# SYMBOL :  PETRONET
# hit : 1
# Growth :  159.74063400576367
# SYMBOL :  MONTECARLO
# hit : 1
# Growth :  42.074592074592076
# SYMBOL :  MINDAIND
# hit : 1
# Growth :  205.16176470588235
# SYMBOL :  BANKBARODA
# hit : 1
# Growth :  21.58385093167702
# SYMBOL :  SBIN
# hit : 0
# Growth :  22.179487179487182
# SYMBOL :  MANAPPURAM
# hit : 0
# Growth :  12.5
# SYMBOL :  SUNPHARMA
# hit : 0
# Growth :  8.170914542728635
# SYMBOL :  BHARATFORG
# hit : 1
# Growth :  199.96470588235292
# SYMBOL :  ICICIBANK
# hit : 1
# Growth :  33.988671810868496
# SYMBOL :  BRITANNIA
# hit : 1
# Growth :  52.20569417786307
# SYMBOL :  UNIONBANK
# hit : 1
# Growth :  42.16417910447761
# SYMBOL :  PNB
# hit : 1
# Growth :  52.57142857142856
# SYMBOL :  CHOLAFIN
# hit : 0
# Growth :  9.114035087719307
# SYMBOL :  UPL
# hit : 1
# Growth :  30.145560407569146
# SYMBOL :  NESTLEIND
# hit : 0
# Growth :  6.4201353881607375
# SYMBOL :  BAJFINANCE
# hit : 1
# Growth :  81.60962072155412
# SYMBOL :  BAJAJ-AUTO
# hit : 1
# Growth :  16.161562829989442
# SYMBOL :  BAJAJFINSV
# hit : 1
# Growth :  65.79814921920186
# SYMBOL :  MARUTI
# hit : 1
# Growth :  39.23621778460489
# SYMBOL :  STRTECH
# hit : 1
# Growth :  156.7452830188679
# SYMBOL :  CANBK
# hit : 1
# Growth :  41.90322580645161
# SYMBOL :  HINDUNILVR
# hit : 1
# Growth :  52.274346793349174
# SYMBOL :  DRREDDY
# hit : 0
# Growth :  5.093033792122983
# SYMBOL :  GRANULES
# hit : 0
# Growth :  21.640000000000008
# SYMBOL :  AXISBANK
# hit : 0
# Growth :  11.899383983572905
# SYMBOL :  UNICHEMLAB
# hit : 0
# Growth :  1.154575219713949
# SYMBOL :  KOTAKBANK
# hit : 1
# Growth :  33.64634146341464
# SYMBOL :  APLLTD
# hit : 0
# Growth :  -0.3392330383480759
# SYMBOL :  HDFCBANK
# hit : 1
# Growth :  50.685483870967744
# SYMBOL :  ITC
# hit : 1
# Growth :  43.455497382198956
# SYMBOL :  RELIANCE
# hit : 1
# Growth :  210.0526118000751
# SYMBOL :  HCLTECH
# hit : 1
# Growth :  12.779014499729263
# SYMBOL :  WIPRO
# hit : 1
# Growth :  124.57932692307689
# SYMBOL :  YESBANK
# hit : 1
# Growth :  613.754223453931
# SYMBOL :  TCS
# hit : 1
# Growth :  12.333333333333334
# SYMBOL :  STRTECH
# hit : 1
# Growth :  164.22330097087374
# SYMBOL :  INFY
# hit : 0
# Growth :  0.6501975711787626
# SYMBOL :  TV18BRDCST
# hit : 0
# Growth :  4.462242562929052
# SYMBOL :  INDUSINDBK
# hit : 1
# Growth :  47.67106347897774
# SYMBOL :  AARTIIND
# hit : 1
# Growth :  46.06351550960119
# SYMBOL :  INFIBEAM
# hit : 1
# Growth :  55.25871172122491
# SYMBOL :  KWALITY
# hit : 0
# Growth :  33.30645161290323
# SYMBOL :  GSPL
# hit : 1
# Growth :  34.17508417508417
# SYMBOL :  MRPL
# hit : 1
# Growth :  70.1829268292683
# SYMBOL :  CHENNPETRO
# hit : 1
# Growth :  59.44636678200692
# SYMBOL :  PETRONET
# hit : 1
# Growth :  156.05113636363635
# SYMBOL :  INOXWIND
# hit : 0
# Growth :  32.83625730994152
# SYMBOL :  UFLEX
# hit : 0
# Growth :  72.72200772200773
# SYMBOL :  CIPLA
# hit : 0
# Growth :  15.82386363636363
# SYMBOL :  EMMBI
# hit : 1
# Growth :  72.26890756302521
# SYMBOL :  HEROMOTOCO
# hit : 1
# Growth :  14.483506944444448
# SYMBOL :  INDUSINDBK
# hit : 1
# Growth :  37.970253718285214
# SYMBOL :  NHPC
# hit : 0
# Growth :  -55.50182958703607
# SYMBOL :  CKFSL
# hit : 0
# Growth :  nan
# SYMBOL :  MINDAIND
# hit : 1
# Growth :  581.427955133736
# SYMBOL :  SOLARINDS
# hit : 1
# Growth :  80.4476479514416
# SYMBOL :  BAJFINANCE
# hit : 1
# Growth :  130.15240328253225
# SYMBOL :  INFIBEAM
# hit : 1
# Growth :  31.394101876675595
# SYMBOL :  TV18BRDCST
# hit : 0
# Growth :  50.92105263157895
# SYMBOL :  STRTECH
# hit : 1
# Growth :  212.4468085106383
# SYMBOL :  SCHNEIDER
# hit : 0
# Growth :  11.478873239436627
# SYMBOL :  BALKRISIND
# hit : 1
# Growth :  81.16484440706478
# SYMBOL :  TATAMOTORS
# hit : 0
# Growth :  18.552915766738657
# SYMBOL :  INFIBEAM
# hit : 1
# Growth :  40.69856459330143
# SYMBOL :  EMMBI
# hit : 1
# Growth :  115.56521739130434
# SYMBOL :  IGL
# hit : 1
# Growth :  860.6547619047619
# SYMBOL :  PETRONET
# hit : 1
# Growth :  159.74063400576367
# SYMBOL :  MONTECARLO
# hit : 1
# Growth :  42.074592074592076
# SYMBOL :  MINDAIND
# hit : 1
# Growth :  205.16176470588235
# SYMBOL :  BANKBARODA
# hit : 1
# Growth :  21.58385093167702
# SYMBOL :  SBIN
# hit : 0
# Growth :  22.179487179487182
# SYMBOL :  MANAPPURAM
# hit : 0
# Growth :  12.5
# SYMBOL :  SUNPHARMA
# hit : 0
# Growth :  8.170914542728635
# SYMBOL :  BHARATFORG
# hit : 1
# Growth :  199.96470588235292
# SYMBOL :  ICICIBANK
# hit : 1
# Growth :  33.988671810868496
# SYMBOL :  BRITANNIA
# hit : 1
# Growth :  52.20569417786307
# SYMBOL :  UNIONBANK
# hit : 1
# Growth :  42.16417910447761
# SYMBOL :  PNB
# hit : 1
# Growth :  52.57142857142856
# SYMBOL :  CHOLAFIN
# hit : 0
# Growth :  9.114035087719307
# SYMBOL :  UPL
# hit : 1
# Growth :  30.145560407569146
# SYMBOL :  BAJFINANCE
# hit : 1
# Growth :  81.60962072155412
# SYMBOL :  NESTLEIND
# hit : 0
# Growth :  6.4201353881607375
# SYMBOL :  BAJAJ-AUTO
# hit : 1
# Growth :  16.161562829989442
# SYMBOL :  BAJAJFINSV
# hit : 1
# Growth :  65.79814921920186
# SYMBOL :  MARUTI
# hit : 1
# Growth :  39.23621778460489
# SYMBOL :  STRTECH
# hit : 1
# Growth :  156.7452830188679
# SYMBOL :  CANBK
# hit : 1
# Growth :  41.90322580645161
# SYMBOL :  HINDUNILVR
# hit : 1
# Growth :  52.274346793349174
# SYMBOL :  GRANULES
# hit : 0
# Growth :  21.640000000000008
# SYMBOL :  AXISBANK
# hit : 0
# Growth :  11.899383983572905
# SYMBOL :  UNICHEMLAB
# hit : 0
# Growth :  1.154575219713949
# SYMBOL :  DRREDDY
# hit : 0
# Growth :  5.093033792122983
# SYMBOL :  HDFCBANK
# hit : 1
# Growth :  50.685483870967744
# SYMBOL :  APLLTD
# hit : 0
# Growth :  -0.3392330383480759
# SYMBOL :  KOTAKBANK
# hit : 1
# Growth :  33.64634146341464
# SYMBOL :  ITC
# hit : 1
# Growth :  43.455497382198956
# SYMBOL :  RELIANCE
# hit : 1
# Growth :  210.0526118000751
# SYMBOL :  HCLTECH
# hit : 1
# Growth :  12.779014499729263
# SYMBOL :  WIPRO
# hit : 1
# Growth :  124.57932692307689
# SYMBOL :  YESBANK
# hit : 1
# Growth :  613.754223453931
# SYMBOL :  STRTECH
# hit : 1
# Growth :  164.22330097087374
# SYMBOL :  TCS
# hit : 1
# Growth :  12.333333333333334
# SYMBOL :  INFY
# hit : 0
# Growth :  0.6501975711787626
# SYMBOL :  TV18BRDCST
# hit : 0
# Growth :  4.462242562929052
# SYMBOL :  INDUSINDBK
# hit : 1
# Growth :  47.67106347897774
# SYMBOL :  AARTIIND
# hit : 1
# Growth :  46.06351550960119
# SYMBOL :  INFIBEAM
# hit : 1
# Growth :  55.25871172122491
# SYMBOL :  KWALITY
# hit : 0
# Growth :  33.30645161290323
# SYMBOL :  GSPL
# hit : 1
# Growth :  34.17508417508417
# SYMBOL :  PETRONET
# hit : 1
# Growth :  156.05113636363635
# SYMBOL :  MRPL
# hit : 1
# Growth :  70.1829268292683
# SYMBOL :  CHENNPETRO
# hit : 1
# Growth :  59.44636678200692
# SYMBOL :  INOXWIND
# hit : 0
# Growth :  32.83625730994152
# SYMBOL :  UFLEX
# hit : 0
# Growth :  72.72200772200773
# SYMBOL :  CIPLA
# hit : 0
# Growth :  15.82386363636363
# SYMBOL :  EMMBI
# hit : 1
# Growth :  72.26890756302521
# SYMBOL :  HEROMOTOCO
# hit : 1
# Growth :  14.483506944444448
# SYMBOL :  INDUSINDBK
# hit : 1
# Growth :  37.970253718285214
# SYMBOL :  CKFSL
# hit : 0
# Growth :  nan
# SYMBOL :  NHPC
# hit : 0
# Growth :  -55.50182958703607
# SYMBOL :  MINDAIND
# hit : 1
# Growth :  581.427955133736
# SYMBOL :  ONGC
# hit : 1
# Growth :  118.68647928786712
# SYMBOL :  GAIL
# hit : 1
# Growth :  82.27593152064449
# SYMBOL :  CIPLA
# hit : 0
# Growth :  30.673076923076916
# SYMBOL :  UNICHEMLAB
# hit : 0
# Growth :  17.500000000000004
# SYMBOL :  RELIANCE
# hit : 1
# Growth :  41.86390532544379
# SYMBOL :  HDFCBANK
# hit : 1
# Growth :  40.49817184643509
# SYMBOL :  INDUSINDBK
# hit : 1
# Growth :  46.70918367346939
# brokerName :  AUM Capital
# SYMBOL :  NH
# hit : 0
# Growth :  11.196436799262782
# SYMBOL :  NH
# hit : 0
# Growth :  11.196436799262782
# SYMBOL :  NH
# hit : 0
# Growth :  11.196436799262782
# SYMBOL :  NBCC
# hit : 1
# Growth :  83.91937432441023
# SYMBOL :  WSTCSTPAPR
# hit : 1
# Growth :  113.29372447085034
# SYMBOL :  CHOLAFIN
# hit : 1
# Growth :  124.29446793820661
# SYMBOL :  RBLBANK
# hit : 1
# Growth :  91.5623475857584
# SYMBOL :  EIDPARRY
# hit : 1
# Growth :  44.92063492063491
# SYMBOL :  KESORAMIND
# hit : 0
# Growth :  15.015974440894565
# SYMBOL :  NBCC
# hit : 1
# Growth :  83.91937432441023
# SYMBOL :  WSTCSTPAPR
# hit : 1
# Growth :  113.29372447085034
# SYMBOL :  CHOLAFIN
# hit : 1
# Growth :  124.29446793820661
# SYMBOL :  RBLBANK
# hit : 1
# Growth :  91.5623475857584
# SYMBOL :  EIDPARRY
# hit : 1
# Growth :  44.92063492063491
# SYMBOL :  KESORAMIND
# hit : 0
# Growth :  15.015974440894565
# SYMBOL :  NBCC
# hit : 1
# Growth :  83.91937432441023
# SYMBOL :  WSTCSTPAPR
# hit : 1
# Growth :  113.29372447085034
# SYMBOL :  CHOLAFIN
# hit : 1
# Growth :  124.29446793820661
# SYMBOL :  RBLBANK
# hit : 1
# Growth :  91.5623475857584
# SYMBOL :  EIDPARRY
# hit : 1
# Growth :  44.92063492063491
# SYMBOL :  KESORAMIND
# hit : 0
# Growth :  15.015974440894565
# brokerName :  Religare
# SYMBOL :  ICICIBANK
# hit : 1
# Growth :  49.93340375694668
# SYMBOL :  ICICIBANK
# hit : 1
# Growth :  49.93340375694668
# SYMBOL :  ICICIBANK
# hit : 1
# Growth :  49.93340375694668
# SYMBOL :  RELIANCE
# hit : 1
# Growth :  205.4157103723995
# SYMBOL :  BHARATFIN
# hit : 1
# Growth :  75.33919276388771
# SYMBOL :  GLENMARK
# hit : 0
# Growth :  2.8793565683646136
# SYMBOL :  SUNPHARMA
# hit : 0
# Growth :  4.0626601273698855
# SYMBOL :  BHARTIARTL
# hit : 1
# Growth :  63.392991427282325
# SYMBOL :  DIVISLAB
# hit : 0
# Growth :  0.7047095221725719
# SYMBOL :  GSPL
# hit : 1
# Growth :  47.55033557046979
# SYMBOL :  OIL
# hit : 1
# Growth :  49.81831733904778
# SYMBOL :  SUNPHARMA
# hit : 0
# Growth :  5.760773966578709
# SYMBOL :  LT
# hit : 1
# Growth :  35.75269828137341
# SYMBOL :  YESBANK
# hit : 1
# Growth :  730.6897008792471
# SYMBOL :  GUJGASLTD
# hit : 1
# Growth :  83.28105693375156
# SYMBOL :  PETRONET
# hit : 1
# Growth :  159.17299286864505
# SYMBOL :  VOLTAS
# hit : 1
# Growth :  109.82234369661771
# SYMBOL :  GREENPLY
# hit : 1
# Growth :  16.249314567720706
# SYMBOL :  SHRIRAMCIT
# hit : 0
# Growth :  42.950047653753444
# SYMBOL :  TATAMOTORS
# hit : 0
# Growth :  8.200275970825935
# SYMBOL :  DIVISLAB
# hit : 0
# Growth :  1.569602881893812
# SYMBOL :  M&M
# hit : 1
# Growth :  15.849514563106801
# SYMBOL :  TATASTEEL
# hit : 1
# Growth :  84.60759493670888
# SYMBOL :  SBIN
# hit : 1
# Growth :  19.788112767103616
# SYMBOL :  SUNPHARMA
# hit : 0
# Growth :  3.2115013232243825
# SYMBOL :  CEATLTD
# hit : 1
# Growth :  47.23792787286064
# SYMBOL :  BHEL
# hit : 1
# Growth :  25.069832402234642
# SYMBOL :  MARICO
# hit : 1
# Growth :  25.557620817843866
# SYMBOL :  IOC
# hit : 1
# Growth :  39.435755903097196
# SYMBOL :  COLPAL
# hit : 1
# Growth :  20.90548716878781
# SYMBOL :  STAR
# hit : 1
# Growth :  14.777645659928648
# SYMBOL :  GLENMARK
# hit : 0
# Growth :  6.970687648916715
# SYMBOL :  MCDOWELL-N
# hit : 1
# Growth :  33.19027181688126
# SYMBOL :  NTPC
# hit : 0
# Growth :  21.280788177339904
# SYMBOL :  BAJAJ-AUTO
# hit : 1
# Growth :  15.871984831993265
# SYMBOL :  EICHERMOT
# hit : 1
# Growth :  36.81078268109908
# SYMBOL :  BHARATFIN
# hit : 1
# Growth :  16.412667837516306
# SYMBOL :  CANBK
# hit : 1
# Growth :  39.9840891010342
# SYMBOL :  JSWENERGY
# hit : 1
# Growth :  25.48725637181409
# SYMBOL :  DABUR
# hit : 1
# Growth :  9.774182676103809
# SYMBOL :  HCLTECH
# hit : 1
# Growth :  13.604316105695547
# SYMBOL :  RELIANCE
# hit : 1
# Growth :  203.44992460186106
# SYMBOL :  GAIL
# hit : 1
# Growth :  62.5631019851962
# SYMBOL :  NIITTECH
# hit : 1
# Growth :  49.64451897867113
# SYMBOL :  TCS
# hit : 1
# Growth :  15.762806475159943
# SYMBOL :  INFY
# hit : 0
# Growth :  1.426276590566116
# SYMBOL :  NAUKRI
# hit : 1
# Growth :  32.34508844142842
# SYMBOL :  CIGNITITEC
# hit : 0
# Growth :  14.081145584725537
# SYMBOL :  GREENPLY
# hit : 1
# Growth :  9.909090909090908
# SYMBOL :  SWARAJENG
# hit : 1
# Growth :  101.1697635135135
# SYMBOL :  TATACOMM
# hit : 1
# Growth :  48.008006099885634
# SYMBOL :  YESBANK
# hit : 1
# Growth :  657.3413897280967
# SYMBOL :  ASHOKLEY
# hit : 0
# Growth :  40.71216617210682
# SYMBOL :  TATAMOTORS
# hit : 0
# Growth :  3.6080586080586166
# SYMBOL :  COALINDIA
# hit : 0
# Growth :  2.7760641579272054
# SYMBOL :  TATASTEEL
# hit : 1
# Growth :  82.78907922912204
# SYMBOL :  OIL
# hit : 1
# Growth :  61.67303438568269
