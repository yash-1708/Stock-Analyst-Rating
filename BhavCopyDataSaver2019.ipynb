# %%
import pandas as pd
import numpy as np
import glob
from glob import iglob
import os

from dateutil import parser
from datetime import datetime
from dateutil.relativedelta import relativedelta

import mysql.connector
from sqlalchemy import create_engine
import pandas.io.sql as psql
from dateutil import parser
import sqlalchemy
from datetime import datetime

# %%
path =r'C:\Users\yash\Desktop\2019\*.csv'
all_rec = iglob(path, recursive=True)   
dataframes = (pd.read_csv(f) for f in all_rec)
big_dataframe = pd.concat(dataframes, ignore_index=True)
big_dataframe
# Out:
#             SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST  \
# 0        20MICRONS     EQ     42.05     44.75     41.70     44.25     44.65
# 1       3IINFOTECH     EQ      3.65      3.65      3.60      3.65      3.65
# 2          3MINDIA     EQ  20854.95  20870.00  20625.00  20666.35  20675.00
# 3           3PLAND     EQ     12.00     12.05     12.00     12.00     12.00
# 4           5PAISA     EQ    257.90    257.90    247.60    257.90    257.90
# 5          63MOONS     EQ     98.95    101.90     98.60     99.60     99.15
# 6          8KMILES     EQ    141.20    146.45    136.05    142.30    142.25
# 7         A2ZINFRA     EQ     13.00     13.20     12.90     13.00     13.10
# 8            AARON     SM     44.05     44.25     43.75     44.25     44.25
# 9       AARTIDRUGS     EQ    576.65    579.00    570.35    575.65    579.00
# 10        AARTIIND     EQ   1450.00   1455.30   1430.30   1448.60   1447.05
# 11       AARVEEDEN     EQ     25.65     26.80     25.65     26.05     25.85
# 12           AAVAS     EQ    851.00    865.00    840.00    845.25    843.10
# 13            ABAN     EQ     75.00     75.25     73.70     74.50     74.30
# 14             ABB     EQ   1335.00   1336.75   1312.20   1319.20   1320.00
# 15      ABBOTINDIA     EQ   7550.00   7598.00   7455.15   7580.05   7598.00
# 16       ABCAPITAL     EQ    100.60    100.80     99.40    100.10    100.20
# 17           ABFRL     EQ    202.45    203.10    198.70    199.55    198.90
# 18         ABGSHIP     BZ      2.00      2.10      2.00      2.05      2.10
# 19      ABSLNN50ET     EQ    292.00    292.00    291.05    292.00    292.00
# 20             ACC     EQ   1516.90   1516.90   1475.00   1488.80   1487.00
# 21         ACCELYA     EQ    943.80    956.00    943.80    950.00    949.95
# 22             ACE     EQ     92.20     96.75     91.15     94.40     94.10
# 23        ADANIENT     EQ    160.90    162.35    155.45    157.25    157.05
# 24        ADANIGAS     EQ    101.25    103.50    100.55    101.85    101.80
# 25      ADANIGREEN     EQ     41.85     41.85     41.15     41.40     41.25
# 26      ADANIPORTS     EQ    386.30    390.90    384.05    389.00    390.60
# 27      ADANIPOWER     EQ     51.00     51.15     50.45     50.85     50.95
# 28      ADANITRANS     EQ    199.20    202.35    199.00    200.50    200.85
# 29        ADFFOODS     EQ    270.00    273.45    266.55    270.10    270.85
# ...            ...    ...       ...       ...       ...       ...       ...
# 404087   WHIRLPOOL     EQ   2220.00   2249.00   2178.95   2229.35   2232.00
# 404088  WILLAMAGOR     EQ     14.65     14.65     13.50     13.85     14.15
# 404089  WINDMACHIN     BE     20.20     21.20     19.35     20.45     20.05
# 404090        WIPL     BE     58.70     58.70     56.00     56.00     56.00
# 404091       WIPRO     EQ    257.20    257.50    253.40    256.45    256.50
# 404092  WOCKPHARMA     EQ    286.40    292.50    283.65    287.45    287.80
# 404093    WONDERLA     EQ    279.85    283.75    273.00    282.30    282.30
# 404094       WORTH     SM     45.00     45.00     45.00     45.00     45.00
# 404095  WSTCSTPAPR     EQ    226.00    233.50    225.00    228.90    229.80
# 404096   XCHANGING     EQ     55.10     55.15     53.60     54.05     54.45
# 404097     XELPMOC     EQ     70.00     75.95     67.00     68.50     70.70
# 404098    XLENERGY     BE      0.50      0.50      0.45      0.45      0.50
# 404099   XPROINDIA     EQ     22.10     23.00     20.15     21.15     21.85
# 404100     YESBANK     EQ     70.00     73.55     69.15     73.00     72.90
# 404101        ZEEL     EQ    289.25    307.90    285.45    305.40    305.20
# 404102        ZEEL     P2      5.25      5.30      5.25      5.30      5.30
# 404103    ZEELEARN     EQ     21.70     21.95     21.25     21.35     21.35
# 404104    ZEEMEDIA     EQ      7.05      7.05      7.05      7.05      7.05
# 404105   ZENITHBIR     BE      0.70      0.70      0.60      0.70      0.70
# 404106  ZENITHEXPO     EQ     42.00     42.05     42.00     42.05     42.05
# 404107  ZENSARTECH     EQ    190.00    192.15    184.75    190.20    190.00
# 404108      ZENTEC     EQ     64.30     64.65     61.60     62.05     62.10
# 404109       ZICOM     BE      1.45      1.45      1.45      1.45      1.45
# 404110      ZODIAC     SM     25.25     25.25     25.25     25.25     25.25
# 404111  ZODIACLOTH     EQ    184.05    187.90    168.30    186.20    183.00
# 404112   ZODJRDMKJ     EQ     33.10     35.95     30.90     32.45     32.70
# 404113        ZOTA     EQ    183.35    193.00    183.35    190.70    193.00
# 404114       ZUARI     EQ     89.20     90.85     87.30     88.90     88.75
# 404115   ZUARIGLOB     EQ     60.15     60.15     57.65     58.10     58.20
# 404116   ZYDUSWELL     EQ   1605.00   1640.00   1572.00   1589.20   1589.95
#
#         PREVCLOSE  TOTTRDQTY     TOTTRDVAL    TIMESTAMP  TOTALTRADES  \
# 0           42.20      77060  3.401230e+06  01-JAN-2019          501
# 1            3.60     461520  1.675895e+06  01-JAN-2019          259
# 2        20824.40        517  1.072820e+07  01-JAN-2019          302
# 3           12.00        101  1.212050e+03  01-JAN-2019            4
# 4          245.65       3711  9.570281e+05  01-JAN-2019           73
# 5           98.80     259452  2.594292e+07  01-JAN-2019         3205
# 6          140.95     492230  6.979515e+07  01-JAN-2019         6251
# 7           13.05     128562  1.673461e+06  01-JAN-2019          274
# 8           44.25      12000  5.281500e+05  01-JAN-2019            4
# 9          576.65       3283  1.888151e+06  01-JAN-2019          242
# 10        1443.70      13244  1.914779e+07  01-JAN-2019         1632
# 11          25.20       5320  1.390209e+05  01-JAN-2019           51
# 12         857.50      15420  1.306923e+07  01-JAN-2019         1413
# 13          74.75     412633  3.069827e+07  01-JAN-2019         4460
# 14        1336.75      66089  8.754966e+07  01-JAN-2019         3815
# 15        7516.65        968  7.311469e+06  01-JAN-2019          365
# 16         100.00     968494  9.694296e+07  01-JAN-2019         7194
# 17         202.50     680668  1.362633e+08  01-JAN-2019         5100
# 18           2.10      22830  4.695240e+04  01-JAN-2019           46
# 19         291.00        202  5.896975e+04  01-JAN-2019            3
# 20        1508.10     840791  1.252276e+09  01-JAN-2019        23001
# 21         949.95        817  7.757046e+05  01-JAN-2019          314
# 22          91.20     307306  2.917262e+07  01-JAN-2019         2844
# 23         161.00    4726656  7.469025e+08  01-JAN-2019        26782
# 24         100.80     501670  5.122180e+07  01-JAN-2019         4149
# 25          41.85     105166  4.359390e+06  01-JAN-2019          781
# 26         387.70    1233249  4.766379e+08  01-JAN-2019        11481
# 27          50.95    6302024  3.204041e+08  01-JAN-2019         7706
# 28         198.40      66954  1.343098e+07  01-JAN-2019         1378
# 29         269.65      19989  5.395482e+06  01-JAN-2019         1123
# ...           ...        ...           ...          ...          ...
# 404087    2199.45     143077  3.193120e+08  11-NOV-2019         9066
# 404088      14.00       3284  4.593090e+04  11-NOV-2019          270
# 404089      20.25       4818  9.801205e+04  11-NOV-2019           46
# 404090      58.70       2743  1.536350e+05  11-NOV-2019            4
# 404091     256.40    1902379  4.860958e+08  11-NOV-2019        29116
# 404092     286.75     437114  1.257648e+08  11-NOV-2019        11968
# 404093     276.15      39870  1.117409e+07  11-NOV-2019         2771
# 404094      44.50       1500  6.750000e+04  11-NOV-2019            1
# 404095     225.65     107122  2.460123e+07  11-NOV-2019         2241
# 404096      53.75      35708  1.948357e+06  11-NOV-2019          110
# 404097      70.00       3990  2.840358e+05  11-NOV-2019          351
# 404098       0.50       7328  3.590200e+03  11-NOV-2019           16
# 404099      22.55      12476  2.634475e+05  11-NOV-2019          134
# 404100      68.95  263947818  1.894914e+10  11-NOV-2019       582022
# 404101     287.50   20972910  6.288355e+09  11-NOV-2019       180709
# 404102       5.25      46412  2.452640e+05  11-NOV-2019           27
# 404103      21.70      32374  6.985937e+05  11-NOV-2019          449
# 404104       6.75     341890  2.410324e+06  11-NOV-2019          177
# 404105       0.65      30480  1.899150e+04  11-NOV-2019           37
# 404106      44.00          3  1.261000e+02  11-NOV-2019            3
# 404107     189.15      46806  8.810616e+06  11-NOV-2019         3251
# 404108      64.40      58745  3.682273e+06  11-NOV-2019          732
# 404109       1.40      27035  3.920075e+04  11-NOV-2019            9
# 404110      27.30       2000  5.050000e+04  11-NOV-2019            1
# 404111     187.00       1393  2.523647e+05  11-NOV-2019           95
# 404112      32.65       5744  1.907370e+05  11-NOV-2019          249
# 404113     183.35      32624  6.081745e+06  11-NOV-2019          227
# 404114      92.20      86397  7.696726e+06  11-NOV-2019         1785
# 404115      61.15      61407  3.579155e+06  11-NOV-2019          704
# 404116    1620.70       9774  1.562376e+07  11-NOV-2019         1579
#
#                 ISIN
# 0       INE144J01027
# 1       INE748C01020
# 2       INE470A01017
# 3       INE105C01023
# 4       INE618L01018
# 5       INE111B01023
# 6       INE650K01021
# 7       INE619I01012
# 8       INE721Z01010
# 9       INE767A01016
# 10      INE769A01020
# 11      INE273D01019
# 12      INE216P01012
# 13      INE421A01028
# 14      INE117A01022
# 15      INE358A01014
# 16      INE674K01013
# 17      INE647O01011
# 18      INE067H01016
# 19      INF209KB1B87
# 20      INE012A01025
# 21      INE793A01012
# 22      INE731H01025
# 23      INE423A01024
# 24      INE399L01023
# 25      INE364U01010
# 26      INE742F01042
# 27      INE814H01011
# 28      INE931S01010
# 29      INE982B01019
# ...              ...
# 404087  INE716A01013
# 404088  INE210A01017
# 404089  INE052A01021
# 404090  INE215F01023
# 404091  INE075A01022
# 404092  INE049B01025
# 404093  INE066O01014
# 404094  INE196Y01018
# 404095  INE976A01021
# 404096  INE692G01013
# 404097  INE01P501012
# 404098  INE183H01011
# 404099  INE445C01015
# 404100  INE528G01027
# 404101  INE256A01028
# 404102  INE256A04022
# 404103  INE565L01011
# 404104  INE966H01019
# 404105  INE318D01020
# 404106  INE058B01018
# 404107  INE520A01027
# 404108  INE251B01027
# 404109  INE871B01014
# 404110  INE761Y01019
# 404111  INE206B01013
# 404112  INE077B01018
# 404113  INE358U01012
# 404114  INE840M01016
# 404115  INE217A01012
# 404116  INE768C01010
#
# [404117 rows x 13 columns]

# %%
del big_dataframe['OPEN']
del big_dataframe['HIGH']
del big_dataframe['LOW']
del big_dataframe['SERIES']
del big_dataframe['LAST']
del big_dataframe['PREVCLOSE']
del big_dataframe['TOTTRDQTY']
del big_dataframe['TOTTRDVAL']
del big_dataframe['TOTALTRADES']
del big_dataframe['ISIN']

# %%
big_dataframe.columns = ['Symbol','Closeval','Date']
big_dataframe
# Out:
#             Symbol  Closeval         Date
# 0        20MICRONS     44.25  01-JAN-2019
# 1       3IINFOTECH      3.65  01-JAN-2019
# 2          3MINDIA  20666.35  01-JAN-2019
# 3           3PLAND     12.00  01-JAN-2019
# 4           5PAISA    257.90  01-JAN-2019
# 5          63MOONS     99.60  01-JAN-2019
# 6          8KMILES    142.30  01-JAN-2019
# 7         A2ZINFRA     13.00  01-JAN-2019
# 8            AARON     44.25  01-JAN-2019
# 9       AARTIDRUGS    575.65  01-JAN-2019
# 10        AARTIIND   1448.60  01-JAN-2019
# 11       AARVEEDEN     26.05  01-JAN-2019
# 12           AAVAS    845.25  01-JAN-2019
# 13            ABAN     74.50  01-JAN-2019
# 14             ABB   1319.20  01-JAN-2019
# 15      ABBOTINDIA   7580.05  01-JAN-2019
# 16       ABCAPITAL    100.10  01-JAN-2019
# 17           ABFRL    199.55  01-JAN-2019
# 18         ABGSHIP      2.05  01-JAN-2019
# 19      ABSLNN50ET    292.00  01-JAN-2019
# 20             ACC   1488.80  01-JAN-2019
# 21         ACCELYA    950.00  01-JAN-2019
# 22             ACE     94.40  01-JAN-2019
# 23        ADANIENT    157.25  01-JAN-2019
# 24        ADANIGAS    101.85  01-JAN-2019
# 25      ADANIGREEN     41.40  01-JAN-2019
# 26      ADANIPORTS    389.00  01-JAN-2019
# 27      ADANIPOWER     50.85  01-JAN-2019
# 28      ADANITRANS    200.50  01-JAN-2019
# 29        ADFFOODS    270.10  01-JAN-2019
# ...            ...       ...          ...
# 404087   WHIRLPOOL   2229.35  11-NOV-2019
# 404088  WILLAMAGOR     13.85  11-NOV-2019
# 404089  WINDMACHIN     20.45  11-NOV-2019
# 404090        WIPL     56.00  11-NOV-2019
# 404091       WIPRO    256.45  11-NOV-2019
# 404092  WOCKPHARMA    287.45  11-NOV-2019
# 404093    WONDERLA    282.30  11-NOV-2019
# 404094       WORTH     45.00  11-NOV-2019
# 404095  WSTCSTPAPR    228.90  11-NOV-2019
# 404096   XCHANGING     54.05  11-NOV-2019
# 404097     XELPMOC     68.50  11-NOV-2019
# 404098    XLENERGY      0.45  11-NOV-2019
# 404099   XPROINDIA     21.15  11-NOV-2019
# 404100     YESBANK     73.00  11-NOV-2019
# 404101        ZEEL    305.40  11-NOV-2019
# 404102        ZEEL      5.30  11-NOV-2019
# 404103    ZEELEARN     21.35  11-NOV-2019
# 404104    ZEEMEDIA      7.05  11-NOV-2019
# 404105   ZENITHBIR      0.70  11-NOV-2019
# 404106  ZENITHEXPO     42.05  11-NOV-2019
# 404107  ZENSARTECH    190.20  11-NOV-2019
# 404108      ZENTEC     62.05  11-NOV-2019
# 404109       ZICOM      1.45  11-NOV-2019
# 404110      ZODIAC     25.25  11-NOV-2019
# 404111  ZODIACLOTH    186.20  11-NOV-2019
# 404112   ZODJRDMKJ     32.45  11-NOV-2019
# 404113        ZOTA    190.70  11-NOV-2019
# 404114       ZUARI     88.90  11-NOV-2019
# 404115   ZUARIGLOB     58.10  11-NOV-2019
# 404116   ZYDUSWELL   1589.20  11-NOV-2019
#
# [404117 rows x 3 columns]

# %%
big_dataframe['Date'] = pd.to_datetime(big_dataframe['Date'], format = "%d-%b-%Y")

# %%
big_dataframe
# Out:
#             Symbol  Closeval       Date
# 0        20MICRONS     44.25 2019-01-01
# 1       3IINFOTECH      3.65 2019-01-01
# 2          3MINDIA  20666.35 2019-01-01
# 3           3PLAND     12.00 2019-01-01
# 4           5PAISA    257.90 2019-01-01
# 5          63MOONS     99.60 2019-01-01
# 6          8KMILES    142.30 2019-01-01
# 7         A2ZINFRA     13.00 2019-01-01
# 8            AARON     44.25 2019-01-01
# 9       AARTIDRUGS    575.65 2019-01-01
# 10        AARTIIND   1448.60 2019-01-01
# 11       AARVEEDEN     26.05 2019-01-01
# 12           AAVAS    845.25 2019-01-01
# 13            ABAN     74.50 2019-01-01
# 14             ABB   1319.20 2019-01-01
# 15      ABBOTINDIA   7580.05 2019-01-01
# 16       ABCAPITAL    100.10 2019-01-01
# 17           ABFRL    199.55 2019-01-01
# 18         ABGSHIP      2.05 2019-01-01
# 19      ABSLNN50ET    292.00 2019-01-01
# 20             ACC   1488.80 2019-01-01
# 21         ACCELYA    950.00 2019-01-01
# 22             ACE     94.40 2019-01-01
# 23        ADANIENT    157.25 2019-01-01
# 24        ADANIGAS    101.85 2019-01-01
# 25      ADANIGREEN     41.40 2019-01-01
# 26      ADANIPORTS    389.00 2019-01-01
# 27      ADANIPOWER     50.85 2019-01-01
# 28      ADANITRANS    200.50 2019-01-01
# 29        ADFFOODS    270.10 2019-01-01
# ...            ...       ...        ...
# 404087   WHIRLPOOL   2229.35 2019-11-11
# 404088  WILLAMAGOR     13.85 2019-11-11
# 404089  WINDMACHIN     20.45 2019-11-11
# 404090        WIPL     56.00 2019-11-11
# 404091       WIPRO    256.45 2019-11-11
# 404092  WOCKPHARMA    287.45 2019-11-11
# 404093    WONDERLA    282.30 2019-11-11
# 404094       WORTH     45.00 2019-11-11
# 404095  WSTCSTPAPR    228.90 2019-11-11
# 404096   XCHANGING     54.05 2019-11-11
# 404097     XELPMOC     68.50 2019-11-11
# 404098    XLENERGY      0.45 2019-11-11
# 404099   XPROINDIA     21.15 2019-11-11
# 404100     YESBANK     73.00 2019-11-11
# 404101        ZEEL    305.40 2019-11-11
# 404102        ZEEL      5.30 2019-11-11
# 404103    ZEELEARN     21.35 2019-11-11
# 404104    ZEEMEDIA      7.05 2019-11-11
# 404105   ZENITHBIR      0.70 2019-11-11
# 404106  ZENITHEXPO     42.05 2019-11-11
# 404107  ZENSARTECH    190.20 2019-11-11
# 404108      ZENTEC     62.05 2019-11-11
# 404109       ZICOM      1.45 2019-11-11
# 404110      ZODIAC     25.25 2019-11-11
# 404111  ZODIACLOTH    186.20 2019-11-11
# 404112   ZODJRDMKJ     32.45 2019-11-11
# 404113        ZOTA    190.70 2019-11-11
# 404114       ZUARI     88.90 2019-11-11
# 404115   ZUARIGLOB     58.10 2019-11-11
# 404116   ZYDUSWELL   1589.20 2019-11-11
#
# [404117 rows x 3 columns]

# %%
database_username = 'root'
database_password = 'yash'
database_ip       = '127.0.0.1'
database_name     = 'mainschema'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name))

# %%
df1 = big_dataframe.iloc[:50000, :]
df2 = big_dataframe.iloc[50001:100000, :]
df3 = big_dataframe.iloc[100001:150000, :]
df4 = big_dataframe.iloc[150001:200000, :]
df5 = big_dataframe.iloc[200001:250000, :]
df6 = big_dataframe.iloc[250001:300000, :]
df7 = big_dataframe.iloc[300001:350000, :]
df8 = big_dataframe.iloc[350001:400000, :]
df9 = big_dataframe.iloc[400001:, :]

# %%
df1.to_sql(con=database_connection, name='nse2019', if_exists='append')

# %%
df2.to_sql(con=database_connection, name='nse2019', if_exists='append')

# %%
df3.to_sql(con=database_connection, name='nse2019', if_exists='append')

# %%
df4.to_sql(con=database_connection, name='nse2019', if_exists='append')

# %%
df5.to_sql(con=database_connection, name='nse2019', if_exists='append')

# %%
df6.to_sql(con=database_connection, name='nse2019', if_exists='append')

# %%
df7.to_sql(con=database_connection, name='nse2019', if_exists='append')

# %%
df8.to_sql(con=database_connection, name='nse2019', if_exists='append')

# %%
df9.to_sql(con=database_connection, name='nse2019', if_exists='append')
