# %%
import pandas as pd

from dateutil import parser
from datetime import datetime
from dateutil.relativedelta import relativedelta

#import mysql.connector
from sqlalchemy import create_engine
import pandas.io.sql as psql
import sqlalchemy

# %%
database_username = 'smarsproddbuser@mbt-smars-mysql'
database_password = 'modern@1234'
database_ip       = 'mbt-smars-mysql.mysql.database.azure.com'
database_name     = 'mainschema'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name))

# %%
df = pd.read_sql('SELECT * FROM notmapped', con=database_connection)

# %%
del df['index']
df
# Out:
#               recoName SYMBOL
# 0   sahyadriindustries   None
# 1             wimplast   None
# 2   mahindraepcirrigat   None
# 3   kesarpetroproducts   None
# 4      sandurmanganese   None
# 5       multibaseindia   None
# 6        asiindustries   None
# 7   rajratanglobalwire   None
# 8              paushak   None
# 9     nationalperoxide   None
# 10         grauer&weil   None
# 11  rciindustries&tech   None
# 12         singerindia   None
# 13   lakshmielectcontl   None
# 14  morganitecruciblei   None
# 15           rotopumps   None
# 16      tigerlogistics   None
# 17    kanpurplastipack   None
# 18        premcoglobal   None
# 19       dishmanpharma   None
# 20  panasonicenergyind   None
# 21          ionexchage   None
# 22       indiahomeloan   None
# 23   shailyenggplastic   None
# 24          cairnindia   None
# 25           geometric   None
# 26       goodyearindia   None
# 27    kirloskarferrous   None
# 28       primaplastics   None
# 29         ultramarine   None
# 30    simmondsmarshall   None
# 31         nglfinechem   None
# 32     kritiindustries   None
# 33    elantasbeckindia   None
# 34    veerenergy&infra   None
# 35  nationalplasticind   None
# 36  kovaimedicalcenter   None
# 37    ganeshbenzoplast   None
# 38                wpil   None
# 39              nirlon   None

# %%
for i in df['recoName']:
    print(i)
    print('Do you wish to enter the nse symbol: ')
    choice = input() 
    if choice == 'y' or choice == 'Y':
        print('Enter the NSE symbol: ')
        symbol = input()
        #append in db
        sqlupdate = "UPDATE symbolsmapped SET SYMBOL='"+symbol+"' WHERE recoName='"+i+"'"
        database_connection.execute(sqlupdate)
    elif choice=='s' or choice=='S':
        continue
    else:
        break
# Out:
# sahyadriindustries
# Do you wish to enter the nse symbol:
# s
# wimplast
# Do you wish to enter the nse symbol:
# s
# mahindraepcirrigat
# Do you wish to enter the nse symbol:
# s
# kesarpetroproducts
# Do you wish to enter the nse symbol:
# s
# sandurmanganese
# Do you wish to enter the nse symbol:
# s
# multibaseindia
# Do you wish to enter the nse symbol:
# s
# asiindustries
# Do you wish to enter the nse symbol:
# s
# rajratanglobalwire
# Do you wish to enter the nse symbol:
# s
# paushak
# Do you wish to enter the nse symbol:
# s
# nationalperoxide
# Do you wish to enter the nse symbol:
# s
# grauer&weil
# Do you wish to enter the nse symbol:
# s
# rciindustries&tech
# Do you wish to enter the nse symbol:
# s
# singerindia
# Do you wish to enter the nse symbol:
# s
# lakshmielectcontl
# Do you wish to enter the nse symbol:
# s
# morganitecruciblei
# Do you wish to enter the nse symbol:
# s
# rotopumps
# Do you wish to enter the nse symbol:
# s
# tigerlogistics
# Do you wish to enter the nse symbol:
# s
# kanpurplastipack
# Do you wish to enter the nse symbol:
# s
# premcoglobal
# Do you wish to enter the nse symbol:
# s
# dishmanpharma
# Do you wish to enter the nse symbol:
# s
# panasonicenergyind
# Do you wish to enter the nse symbol:
# s
# ionexchage
# Do you wish to enter the nse symbol:
# s
# indiahomeloan
# Do you wish to enter the nse symbol:
# s
# shailyenggplastic
# Do you wish to enter the nse symbol:
# s
# cairnindia
# Do you wish to enter the nse symbol:
# s
# geometric
# Do you wish to enter the nse symbol:
# s
# goodyearindia
# Do you wish to enter the nse symbol:
# s
# kirloskarferrous
# Do you wish to enter the nse symbol:
# s
# primaplastics
# Do you wish to enter the nse symbol:
# s
# ultramarine
# Do you wish to enter the nse symbol:
# s
# simmondsmarshall
# Do you wish to enter the nse symbol:
# s
# nglfinechem
# Do you wish to enter the nse symbol:
# s
# kritiindustries
# Do you wish to enter the nse symbol:
# s
# elantasbeckindia
# Do you wish to enter the nse symbol:
# s
# veerenergy&infra
# Do you wish to enter the nse symbol:
# s
# nationalplasticind
# Do you wish to enter the nse symbol:
# s
# kovaimedicalcenter
# Do you wish to enter the nse symbol:
# s
# ganeshbenzoplast
# Do you wish to enter the nse symbol:
# s
# wpil
# Do you wish to enter the nse symbol:
# s
# nirlon
# Do you wish to enter the nse symbol:
# s
