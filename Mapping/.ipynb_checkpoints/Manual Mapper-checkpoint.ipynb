# %%
import pandas as pd

from dateutil import parser
from datetime import datetime
from dateutil.relativedelta import relativedelta

#import mysql.connector
from sqlalchemy import create_engine
import pandas.io.sql as psql
import sqlalchemy

# %%
database_username = 'smarsproddbuser@mbt-smars-mysql'
database_password = 'modern@1234'
database_ip       = 'mbt-smars-mysql.mysql.database.azure.com'
database_name     = 'mainschema'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name))

# %%
df = pd.read_sql('SELECT * FROM notmapped', con=database_connection)

# %%
del df['index']
df
# Out:
#                recoName SYMBOL
# 0    sahyadriindustries   None
# 1              wimplast   None
# 2    mahindraepcirrigat   None
# 3    kesarpetroproducts   None
# 4       sandurmanganese   None
# 5        multibaseindia   None
# 6         asiindustries   None
# 7    rajratanglobalwire   None
# 8               paushak   None
# 9      nationalperoxide   None
# 10          grauer&weil   None
# 11   rciindustries&tech   None
# 12          singerindia   None
# 13    lakshmielectcontl   None
# 14         sreiinfrafin   None
# 15   morganitecruciblei   None
# 16          igpetrochem   None
# 17    garwaretechfibres   None
# 18    oraclefinlservice   None
# 19            rotopumps   None
# 20     sintexindustries   None
# 21       tigerlogistics   None
# 22     actionconstequip   None
# 23      ptcindiafinserv   None
# 24             inoxwind   None
# 25     entertainnetwork   None
# 26                  kcp   None
# 27           andhrabank   None
# 28                 gmdc   None
# 29          l&tinfotech   None
# ..                  ...    ...
# 78      jindalstainless   None
# 79          bandhanbank   None
# 80     bhansalienggpoly   None
# 81        primaplastics   None
# 82     dollarindustries   None
# 83       tvselectronics   None
# 84     blsinternatlserv   None
# 85     rppinfraprojects   None
# 86              nelcast   None
# 87          ultramarine   None
# 88            shalbyltd   None
# 89     simmondsmarshall   None
# 90                 gnfc   None
# 91          nglfinechem   None
# 92      kritiindustries   None
# 93      mircelectronics   None
# 94     elantasbeckindia   None
# 95     veerenergy&infra   None
# 96     masfinancialserv   None
# 97          arcotechltd   None
# 98                  hil   None
# 99   nationalplasticind   None
# 100  kovaimedicalcenter   None
# 101    ganeshbenzoplast   None
# 102      iolchem&pharma   None
# 103       eonelectronic   None
# 104                wpil   None
# 105    rajshreepolypack   None
# 106              nirlon   None
# 107     hdfcassetmngtco   None
#
# [108 rows x 2 columns]

# %%
for i in df['recoName']:
    print(i)
    print('Do you wish to enter the nse symbol: ')
    choice = input() 
    if choice == 'y' or choice == 'Y':
        print('Enter the NSE symbol: ')
        symbol = input()
        #append in db
        sqlupdate = "UPDATE symbolsmapped SET SYMBOL='"+symbol+"' WHERE recoName='"+i+"'"
        database_connection.execute(sqlupdate)
    elif choice=='s' or choice=='S':
        continue
    else:
        break
# Out:
# sahyadriindustries
# Do you wish to enter the nse symbol:
# s
# wimplast
# Do you wish to enter the nse symbol:
# s
# mahindraepcirrigat
# Do you wish to enter the nse symbol:
# s
# kesarpetroproducts
# Do you wish to enter the nse symbol:
# s
# sandurmanganese
# Do you wish to enter the nse symbol:
# s
# multibaseindia
# Do you wish to enter the nse symbol:
# s
# asiindustries
# Do you wish to enter the nse symbol:
# s
# rajratanglobalwire
# Do you wish to enter the nse symbol:
# s
# paushak
# Do you wish to enter the nse symbol:
# s
# nationalperoxide
# Do you wish to enter the nse symbol:
# s
# grauer&weil
# Do you wish to enter the nse symbol:
# s
# rciindustries&tech
# Do you wish to enter the nse symbol:
# s
# singerindia
# Do you wish to enter the nse symbol:
# s
# lakshmielectcontl
# Do you wish to enter the nse symbol:
# s
# sreiinfrafin
# Do you wish to enter the nse symbol:
# y
# Enter the NSE symbol:
# SREINFRA
# morganitecruciblei
# Do you wish to enter the nse symbol:
# s
# igpetrochem
# Do you wish to enter the nse symbol:
# y
# Enter the NSE symbol:
# IGPL
# garwaretechfibres
# Do you wish to enter the nse symbol:
# y
# Enter the NSE symbol:
# GARFIBRES
# oraclefinlservice
# Do you wish to enter the nse symbol:
# y
# Enter the NSE symbol:
# OFSS
# rotopumps
# Do you wish to enter the nse symbol:
# s
# sintexindustries
# Do you wish to enter the nse symbol:
# y
# Enter the NSE symbol:
# SINTEX
# tigerlogistics
# Do you wish to enter the nse symbol:
# s
# actionconstequip
# Do you wish to enter the nse symbol:
# y
# Enter the NSE symbol:
# ACE
# ptcindiafinserv
# Do you wish to enter the nse symbol:
# y
# Enter the NSE symbol:
# PFS
# inoxwind
# Do you wish to enter the nse symbol:
# y
# Enter the NSE symbol:
# INOXWIND
# entertainnetwork
# Do you wish to enter the nse symbol:
# y
# Enter the NSE symbol:
# ENIL
# kcp
# Do you wish to enter the nse symbol:
# y
# Enter the NSE symbol:
# KCP
# andhrabank
# Do you wish to enter the nse symbol:
# y
# Enter the NSE symbol:
# ANDHRABANK
# gmdc
# Do you wish to enter the nse symbol:
# y
# Enter the NSE symbol:
# GMDCLTD
# l&tinfotech
# Do you wish to enter the nse symbol:
