# %%
import pandas as pd
import numpy as np

import mysql.connector
from sqlalchemy import create_engine
import pandas.io.sql as psql
import sqlalchemy

from dateutil import parser
from datetime import datetime
from datetime import date
from dateutil.relativedelta import relativedelta

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix

# %%
database_username = 'smarsproddbuser@mbt-smars-mysql'
database_password = 'modern@1234'
database_ip       = 'mbt-smars-mysql.mysql.database.azure.com'
database_name     = 'mainschema'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name))

# %%
perf2016 = pd.read_sql('SELECT * FROM brokerperformance2016', con=database_connection)
del perf2016['index']
perf2016.rename(columns = {'Hit Ratio':'hr2016', 'Avg. Growth':'ag2016', 
                              'Total Recos':'tr2016'}, inplace = True)
perf2016
# Out:
#                                        Name  hr2016  ag2016  tr2016
# 0                                 KRChoksey      69      50     117
# 1                               AUM Capital      77      70       9
# 2                                  Religare      79      36     222
# 3                         Enochventures.com      52      34      17
# 4                                 Edelweiss      72      35     278
# 5                             Motilal Oswal      69      37     299
# 6                          Kotak Securities      82      43      75
# 7                             Angel Broking      54      36      66
# 8                 Geojit Financial Services      83      42     118
# 9                                   Centrum      72      40     127
# 10                                     IIFL      68      45      29
# 11                          ICICIdirect.com      77      46     428
# 12                              Axis Direct      79      44     264
# 13                             Moneylicious      82      62      17
# 14                            CD Equisearch      77      45      27
# 15                              Nirmal Bang      67      24      55
# 16                  Arihant Capital Markets      87      41      54
# 17                      Prabhudas Lilladher      68      39     183
# 18                       Wallfort Financial       0       0       2
# 19                          HDFC Securities      84      54      25
# 20            Rudra Shares & Stocks Brokers      75      30       4
# 21                             GEPL Capital      75      31       4
# 22                           Dynamic Levels      84      65      53
# 23                    Choice Equity Broking     100      16       2
# 24                           Right Horizons      80      42      10
# 25               Systematix Shares & Stocks     100      45       9
# 26                East India Securities Ltd      80     221      10
# 27                            Sethi Finmart      50      49       8
# 28                       Maximus Securities     100      36       2
# 29                             Ajcon Global       0       0       4
# 30                             India Nivesh      85      60       7
# 31                               Way2Wealth      66      28      18
# 32                           YES Securities      85      29      20
# 33                               AnandRathi      57      35      19
# 34                           SPA Securities      65      46      55
# 35                     Khambatta Securities      66      26      18
# 36                      Reliance Securities      73      35      87
# 37                            Dolat Capital      60      32      30
# 38                   LKP Securities Limited       0       0       4
# 39                 Cholamandalam Securities       0       0       2
# 40                             JM Financial      65      33      29
# 41                     Ashika Stock Broking     100      18       2
# 42                    Antique Stock Broking     100      13       1
# 43                      Karvy Stock Broking      85      63      14
# 44            Blue Ocean Strategic Advisors      50      38       4
# 45                                Sharekhan      54      16      11
# 46                     Precision Technicals      75      51       4
# 47                    Investment Imperative     100      92       1
# 48      Avinash Gorakshakar - Market Expert     100      11       2
# 49                           Hem Securities     100      56       1
# 50                        Powermywealth.com      66      43      18
# 51                          Shahina Mukadam      60      11      10
# 52  Equinomics Research & Advisory Pvt. Ltd     100      88       2
# 53                          Prakashgaba.com      66      24       3
# 54                  Asian Market Securities     100      71       4
# 55                            Elara Capital     100      81       2
# 56                             SMC Research      66      31       9
# 57                          Prakashdiwan.in     100      64       1
# 58                          Phillip Capital     100      31       2

# %%
perf2017 = pd.read_sql('SELECT * FROM brokerperformance2017', con=database_connection)
del perf2017['index']
perf2017.rename(columns = {'Hit Ratio':'hr2017', 'Avg. Growth':'ag2017', 
                              'Total Recos':'tr2017'}, inplace = True)
perf2017
# Out:
#                     Name  hr2017  ag2017  tr2017
# 0    Indiabulls Ventures      41      79      17
# 1    Indiabulls Ventures      41      79      17
# 2          Motilal Oswal      65      94     775
# 3                Ventura      42      53      14
# 4        ICICIdirect.com      78     137     954
# ..                   ...     ...     ...     ...
# 56          India Nivesh      44      10       9
# 57        Sushil Finance     100      76       2
# 58    Wallfort Financial       0       0       2
# 59          GEPL Capital      60      31       5
# 60  Ashika Stock Broking       0       0       2
#
# [61 rows x 4 columns]

# %%
perf2018 = pd.read_sql('SELECT * FROM brokerperformance2018', con=database_connection)
del perf2018['index']
perf2018.rename(columns = {'Hit Ratio':'hr2018', 'Avg. Growth':'ag2018', 
                              'Total Recos':'tr2018'}, inplace = True)
perf2018
# Out:
#                              Name  hr2018  ag2018  tr2018
# 0           Choice Equity Broking      54     122      11
# 1                            IIFL      50      70      28
# 2   Rudra Shares & Stocks Brokers       0       0       2
# 3             Indiabulls Ventures      42     213      49
# 4                         Ventura      11       9       9
# 5                   Motilal Oswal      36      63     526
# 6                 ICICIdirect.com      46      31     309
# 7                         Centrum      39      20      51
# 8                    JM Financial      36      30      95
# 9       Geojit Financial Services      50      29      64
# 10                      Sharekhan      45      66     104
# 11                HDFC Securities      38      39     161
# 12        Arihant Capital Markets      47      79      48
# 13            Reliance Securities      31      23      69
# 14               Kotak Securities      31      14     230
# 15                    Axis Direct      33      33      56
# 16            Prabhudas Lilladher      39      34     284
# 17              Dalmia Securities      33      27       9
# 18                     AnandRathi      18       8      48
# 19                  Dolat Capital      50      26      88
# 20                   GEPL Capital       0       0       3
# 21                      KRChoksey      41      16      48
# 22      East India Securities Ltd       0       0       3
# 23                      Edelweiss      33      55     464
# 24         LKP Securities Limited      11       3      17
# 25       Cholamandalam Securities      50      61      40
# 26                  Elara Capital      25      15      12
# 27            Investec Securities      69      38      23
# 28                    Nirmal Bang      26      10      23
# 29                 SPA Securities       7      11      13
# 30                  CD Equisearch      33      36      21
# 31                    AUM Capital      33       7       3
# 32                  Angel Broking      36      19      19
# 33                   Ajcon Global      40       9       5
# 34       Joindre Capital Services      37      50       8
# 35                       Religare      50      23       6
# 36            Karvy Stock Broking      42      37       7
# 37                        Bonanza      22      15       9
# 38                   SMC Research       0       0       3
# 39    Narnolia Financial Advisors      60      25       5
# 40                Phillip Capital       0       0       2
# 41                 Dynamic Levels       0       0       1
# 42                 YES Securities      33      26       3
# 43                 Hem Securities       0       0       2
# 44          Antique Stock Broking     100      27       2
# 45                      BP Wealth       0       0       1
# 46           Khambatta Securities       0       0       1
# 47           Ashika Stock Broking       0       0       1
# 48          Investment Imperative       0       0       2
# 49                  Sptulsian.com      50      58       4

# %%
#del dfinalperf

# %%
dfinalperf = perf2016.copy()

# %%
dfinalperf = dfinalperf.merge(perf2017,on = 'Name', how = 'outer')
dfinalperf = dfinalperf.merge(perf2018,on = 'Name', how = 'outer')

# %%
dfinalperf
# Out:
#                            Name  hr2016  ag2016  tr2016  hr2017  ag2017  \
# 0                     KRChoksey    69.0    50.0   117.0    75.0    80.0
# 1                   AUM Capital    77.0    70.0     9.0     NaN     NaN
# 2                      Religare    79.0    36.0   222.0    85.0    64.0
# 3             Enochventures.com    52.0    34.0    17.0    55.0    44.0
# 4                     Edelweiss    72.0    35.0   278.0    71.0    70.0
# ..                          ...     ...     ...     ...     ...     ...
# 69            Ashwanigujral.com     NaN     NaN     NaN   100.0   109.0
# 70          Investec Securities     NaN     NaN     NaN    66.0    65.0
# 71         Globe Capital Market     NaN     NaN     NaN     0.0     0.0
# 72               Sushil Finance     NaN     NaN     NaN   100.0    76.0
# 73  Narnolia Financial Advisors     NaN     NaN     NaN     NaN     NaN
#
#     tr2017  hr2018  ag2018  tr2018
# 0    240.0    41.0    16.0    48.0
# 1      NaN    33.0     7.0     3.0
# 2    102.0    50.0    23.0     6.0
# 3      9.0     NaN     NaN     NaN
# 4    834.0    33.0    55.0   464.0
# ..     ...     ...     ...     ...
# 69     2.0     NaN     NaN     NaN
# 70     3.0    69.0    38.0    23.0
# 71     1.0     NaN     NaN     NaN
# 72     2.0     NaN     NaN     NaN
# 73     NaN    60.0    25.0     5.0
#
# [74 rows x 10 columns]

# %%
dfinal = pd.DataFrame()
for index, row in dfinalperf.iterrows():
    broker = row['Name']
    
    tr2016 = row['tr2016']
    ag2016 = row['ag2016']
    hr2016 = row['hr2016']
    
    tr2017 = row['tr2017']
    ag2017 = row['ag2017']
    hr2017 = row['hr2017']
    
    tr2018 = row['tr2018']
    ag2018 = row['ag2018']
    hr2018 = row['hr2018']
     
    tr = 0
    hr = 0
    ag = 0
    
    if not np.isnan(tr2016):
        tr = tr + tr2016
        ag = ag + (ag2016 * tr2016)
        hr = hr + (hr2016 * tr2016)
        
    if not np.isnan(tr2017):
        tr = tr + tr2017
        ag = ag + (ag2017 * tr2017)
        hr = hr + (hr2017 * tr2017)
        
    if not np.isnan(tr2018):
        tr = tr + tr2018
        ag = ag + (ag2018 * tr2018)
        hr = hr + (hr2018 * tr2018)
    
    hr = int(hr/tr)
    ag = int(ag/tr)
    
    #print ("Broker : ",broker,"Hit Ratio : ",hr,"Avg. Growth : ",ag,"Total Recos. : ",tr)
    dfinal = dfinal.append({'Name':broker,'Hit Ratio':hr,'Avg. Growth':ag,'Total Recos':tr},ignore_index=True)
dfinal = dfinal[['Name','Hit Ratio','Avg. Growth','Total Recos']]
df = dfinal.copy()
dfinal
# Out:
#                            Name  Hit Ratio  Avg. Growth  Total Recos
# 0                     KRChoksey       69.0         63.0        405.0
# 1                   AUM Capital       66.0         54.0         12.0
# 2                      Religare       80.0         44.0        330.0
# 3             Enochventures.com       53.0         37.0         26.0
# 4                     Edelweiss       59.0         59.0       1576.0
# ..                          ...        ...          ...          ...
# 69            Ashwanigujral.com      100.0        109.0          2.0
# 70          Investec Securities       68.0         41.0         26.0
# 71         Globe Capital Market        0.0          0.0          1.0
# 72               Sushil Finance      100.0         76.0          2.0
# 73  Narnolia Financial Advisors       60.0         25.0          5.0
#
# [74 rows x 4 columns]

# %%
X1 = df[['Avg. Growth','Avg. Growth']]
model1 = KMeans(n_clusters=5).fit(X1)
centroids1 = model1.cluster_centers_
sortedcentroids1 = centroids1[:,0].copy()
sortedcentroids1.sort(axis=0)
labeldict1 = {}
for i in centroids1[:,0] :
    x = list(sortedcentroids1).index(i)
    y = list(centroids1[:,0]).index(i)
    labeldict1[y] = x
    unsortedlabels1 = model1.predict(X1)
sortedlabels1 = []
for element in unsortedlabels1 :
    sortedlabels1.append(labeldict1[element]+1)

plt.figure(figsize=(10,10))
plt.scatter(df['Avg. Growth'], df['Avg. Growth'], c= unsortedlabels1, s=25, alpha=0.5)
plt.scatter(centroids1[:, 0], centroids1[:, 1], c='red', s=50)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X2 = df[['Total Recos','Total Recos']]
model2 = KMeans(n_clusters=5).fit(X2)
centroids2 = model2.cluster_centers_
sortedcentroids2 = centroids2[:,0].copy()
sortedcentroids2.sort(axis=0)
labeldict2 = {}
for i in centroids2[:,0] :
    x = list(sortedcentroids2).index(i)
    y = list(centroids2[:,0]).index(i)
    labeldict2[y] = x
    unsortedlabels2 = model2.predict(X2)
sortedlabels2 = []
for element in unsortedlabels2 :
    sortedlabels2.append(labeldict2[element]+1)

plt.figure(figsize=(10,10))
plt.scatter(df['Total Recos'], df['Total Recos'], c= unsortedlabels2, s=25, alpha=0.5)
plt.scatter(centroids2[:, 0], centroids2[:, 1], c='red', s=50)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
X3 = df[['Hit Ratio','Hit Ratio']]
model3 = KMeans(n_clusters=5).fit(X3)
centroids3 = model3.cluster_centers_
sortedcentroids3 = centroids3[:,0].copy()
sortedcentroids3.sort(axis=0)
labeldict3 = {}
for i in centroids3[:,0] :
    x = list(sortedcentroids3).index(i)
    y = list(centroids3[:,0]).index(i)
    labeldict3[y] = x
    unsortedlabels3 = model3.predict(X3)
sortedlabels3 = []
for element in unsortedlabels3 :
    sortedlabels3.append(labeldict3[element]+1)

plt.figure(figsize=(10,10))
plt.scatter(df['Hit Ratio'], df['Hit Ratio'], c= unsortedlabels3, s=25, alpha=0.5)
plt.scatter(centroids3[:, 0], centroids3[:, 1], c='red', s=50)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
dfanalysis = pd.DataFrame({'broker': df['Name'], 'Hit Ratio': sortedlabels3,'Avg. Growth' : sortedlabels1, 'Total Recos' : sortedlabels2})
dfanalysis
# Out:
#                          broker  Hit Ratio  Avg. Growth  Total Recos
# 0                     KRChoksey          4            3            3
# 1                   AUM Capital          3            2            1
# 2                      Religare          4            2            3
# 3             Enochventures.com          3            2            1
# 4                     Edelweiss          3            3            5
# ..                          ...        ...          ...          ...
# 69            Ashwanigujral.com          5            4            1
# 70          Investec Securities          4            2            1
# 71         Globe Capital Market          1            1            1
# 72               Sushil Finance          5            3            1
# 73  Narnolia Financial Advisors          3            1            1
#
# [74 rows x 4 columns]

# %%
dictstar1 = {1:1,   2:0.8, 3:0.6, 4:0.4, 5:0 }
dictstar2 = {1:0.8, 2:1,   3:0.8, 4:0.6, 5:0.4 }
dictstar3 = {1:0.6, 2:0.8, 3:1,   4:0.8, 5:0.6 }
dictstar4 = {1:0.4, 2:0.6, 3:0.8, 4:1,   5:0.6 }
dictstar5 = {1:0.2, 2:0.4, 3:0.6, 4:0.8, 5:1 }

# %%
star = []
for index, row in dfanalysis.iterrows():
    hr = row['Hit Ratio']
    ag = row['Avg. Growth']
    tr = row['Total Recos']
    probabilities = []
    probabilities.append(dictstar1[hr]*dictstar1[ag]*dictstar1[tr]) 
    probabilities.append(dictstar2[hr]*dictstar2[ag]*dictstar2[tr]) 
    probabilities.append(dictstar3[hr]*dictstar3[ag]*dictstar3[tr]) 
    probabilities.append(dictstar4[hr]*dictstar4[ag]*dictstar4[tr]) 
    probabilities.append(dictstar5[hr]*dictstar5[ag]*dictstar5[tr]) 
    rating = probabilities.index(max(probabilities))+1
    star.append(rating)

# %%
dfanalysis['Rating'] = star
dfanalysis
# Out:
#                          broker  Hit Ratio  Avg. Growth  Total Recos  Rating
# 0                     KRChoksey          4            3            3       3
# 1                   AUM Capital          3            2            1       2
# 2                      Religare          4            2            3       3
# 3             Enochventures.com          3            2            1       2
# 4                     Edelweiss          3            3            5       3
# ..                          ...        ...          ...          ...     ...
# 69            Ashwanigujral.com          5            4            1       3
# 70          Investec Securities          4            2            1       2
# 71         Globe Capital Market          1            1            1       1
# 72               Sushil Finance          5            3            1       3
# 73  Narnolia Financial Advisors          3            1            1       1
#
# [74 rows x 5 columns]

# %%
df2016 = pd.read_sql('SELECT * FROM finalrating2016', con=database_connection)
del df2016['index']
df2016
# Out:
#                                      broker  Hit Ratio  Avg. Growth  \
# 0                                 KRChoksey          3            3
# 1                               AUM Capital          4            4
# 2                                  Religare          4            2
# 3                         Enochventures.com          2            2
# 4                                 Edelweiss          3            2
# 5                             Motilal Oswal          3            2
# 6                          Kotak Securities          4            3
# 7                             Angel Broking          2            2
# 8                 Geojit Financial Services          4            3
# 9                                   Centrum          3            3
# 10                                     IIFL          3            3
# 11                          ICICIdirect.com          4            3
# 12                              Axis Direct          4            3
# 13                             Moneylicious          4            4
# 14                            CD Equisearch          4            3
# 15                              Nirmal Bang          3            2
# 16                  Arihant Capital Markets          4            3
# 17                      Prabhudas Lilladher          3            2
# 18                       Wallfort Financial          1            1
# 19                          HDFC Securities          4            3
# 20            Rudra Shares & Stocks Brokers          4            2
# 21                             GEPL Capital          4            2
# 22                           Dynamic Levels          4            4
# 23                    Choice Equity Broking          5            1
# 24                           Right Horizons          4            3
# 25               Systematix Shares & Stocks          5            3
# 26                East India Securities Ltd          4            5
# 27                            Sethi Finmart          2            3
# 28                       Maximus Securities          5            2
# 29                             Ajcon Global          1            1
# 30                             India Nivesh          4            4
# 31                               Way2Wealth          3            2
# 32                           YES Securities          4            2
# 33                               AnandRathi          2            2
# 34                           SPA Securities          3            3
# 35                     Khambatta Securities          3            2
# 36                      Reliance Securities          3            2
# 37                            Dolat Capital          2            2
# 38                   LKP Securities Limited          1            1
# 39                 Cholamandalam Securities          1            1
# 40                             JM Financial          3            2
# 41                     Ashika Stock Broking          5            1
# 42                    Antique Stock Broking          5            1
# 43                      Karvy Stock Broking          4            4
# 44            Blue Ocean Strategic Advisors          2            2
# 45                                Sharekhan          2            1
# 46                     Precision Technicals          4            3
# 47                    Investment Imperative          5            4
# 48      Avinash Gorakshakar - Market Expert          5            1
# 49                           Hem Securities          5            3
# 50                        Powermywealth.com          3            3
# 51                          Shahina Mukadam          2            1
# 52  Equinomics Research & Advisory Pvt. Ltd          5            4
# 53                          Prakashgaba.com          3            2
# 54                  Asian Market Securities          5            4
# 55                            Elara Capital          5            4
# 56                             SMC Research          3            2
# 57                          Prakashdiwan.in          5            4
# 58                          Phillip Capital          5            2
#
#     Total Recos  Rating
# 0             3       3
# 1             1       4
# 2             4       4
# 3             1       2
# 4             4       3
# 5             4       3
# 6             2       3
# 7             2       2
# 8             3       3
# 9             3       3
# 10            1       3
# 11            5       3
# 12            4       4
# 13            1       4
# 14            1       3
# 15            2       2
# 16            2       3
# 17            3       3
# 18            1       1
# 19            1       3
# 20            1       2
# 21            1       2
# 22            2       4
# 23            1       2
# 24            1       3
# 25            1       3
# 26            1       3
# 27            1       2
# 28            1       2
# 29            1       1
# 30            1       4
# 31            1       2
# 32            1       2
# 33            1       2
# 34            2       3
# 35            1       2
# 36            2       2
# 37            1       2
# 38            1       1
# 39            1       1
# 40            1       2
# 41            1       2
# 42            1       2
# 43            1       4
# 44            1       2
# 45            1       1
# 46            1       3
# 47            1       3
# 48            1       2
# 49            1       3
# 50            1       3
# 51            1       1
# 52            1       3
# 53            1       2
# 54            1       3
# 55            1       3
# 56            1       2
# 57            1       3
# 58            1       2

# %%
df2017 = pd.read_sql('SELECT * FROM finalrating2017', con=database_connection)
del df2017['index']
df2017
# Out:
#                   broker  Hit Ratio  Avg. Growth  Total Recos  Rating
# 0    Indiabulls Ventures          2            3            1       2
# 1    Indiabulls Ventures          2            3            1       2
# 2          Motilal Oswal          3            4            5       3
# 3                Ventura          2            2            1       2
# 4        ICICIdirect.com          3            5            5       5
# ..                   ...        ...          ...          ...     ...
# 56          India Nivesh          2            1            1       1
# 57        Sushil Finance          5            3            1       3
# 58    Wallfort Financial          1            1            1       1
# 59          GEPL Capital          3            2            1       2
# 60  Ashika Stock Broking          1            1            1       1
#
# [61 rows x 5 columns]

# %%
df2018 = pd.read_sql('SELECT * FROM finalrating2018', con=database_connection)
del df2018['index']
df2018
# Out:
#                            broker  Hit Ratio  Avg. Growth  Total Recos  Rating
# 0           Choice Equity Broking          4            4            1       4
# 1                            IIFL          4            3            1       3
# 2   Rudra Shares & Stocks Brokers          1            1            1       1
# 3             Indiabulls Ventures          3            5            2       3
# 4                         Ventura          2            1            1       1
# 5                   Motilal Oswal          3            3            5       3
# 6                 ICICIdirect.com          4            2            4       4
# 7                         Centrum          3            2            2       2
# 8                    JM Financial          3            2            3       3
# 9       Geojit Financial Services          4            2            2       2
# 10                      Sharekhan          4            3            3       3
# 11                HDFC Securities          3            2            3       3
# 12        Arihant Capital Markets          4            3            2       3
# 13            Reliance Securities          3            2            2       2
# 14               Kotak Securities          3            1            4       3
# 15                    Axis Direct          3            2            2       2
# 16            Prabhudas Lilladher          3            2            4       3
# 17              Dalmia Securities          3            2            1       2
# 18                     AnandRathi          2            1            2       2
# 19                  Dolat Capital          4            2            3       3
# 20                   GEPL Capital          1            1            1       1
# 21                      KRChoksey          3            1            2       2
# 22      East India Securities Ltd          1            1            1       1
# 23                      Edelweiss          3            3            5       3
# 24         LKP Securities Limited          2            1            1       1
# 25       Cholamandalam Securities          4            3            2       3
# 26                  Elara Capital          2            1            1       1
# 27            Investec Securities          4            2            1       2
# 28                    Nirmal Bang          2            1            1       1
# 29                 SPA Securities          1            1            1       1
# 30                  CD Equisearch          3            2            1       2
# 31                    AUM Capital          3            1            1       1
# 32                  Angel Broking          3            2            1       2
# 33                   Ajcon Global          3            1            1       1
# 34       Joindre Capital Services          3            3            1       3
# 35                       Religare          4            2            1       2
# 36            Karvy Stock Broking          3            2            1       2
# 37                        Bonanza          2            1            1       1
# 38                   SMC Research          1            1            1       1
# 39    Narnolia Financial Advisors          4            2            1       2
# 40                Phillip Capital          1            1            1       1
# 41                 Dynamic Levels          1            1            1       1
# 42                 YES Securities          3            2            1       2
# 43                 Hem Securities          1            1            1       1
# 44          Antique Stock Broking          5            2            1       2
# 45                      BP Wealth          1            1            1       1
# 46           Khambatta Securities          1            1            1       1
# 47           Ashika Stock Broking          1            1            1       1
# 48          Investment Imperative          1            1            1       1
# 49                  Sptulsian.com          4            3            1       3

# %%
df20161718 = pd.concat([df2016, df2017,df2018], ignore_index=True)
df20161718
# Out:
#                     broker  Hit Ratio  Avg. Growth  Total Recos  Rating
# 0                KRChoksey          3            3            3       3
# 1              AUM Capital          4            4            1       4
# 2                 Religare          4            2            4       4
# 3        Enochventures.com          2            2            1       2
# 4                Edelweiss          3            2            4       3
# ..                     ...        ...          ...          ...     ...
# 165              BP Wealth          1            1            1       1
# 166   Khambatta Securities          1            1            1       1
# 167   Ashika Stock Broking          1            1            1       1
# 168  Investment Imperative          1            1            1       1
# 169          Sptulsian.com          4            3            1       3
#
# [170 rows x 5 columns]

# %%
Xtrain = df20161718[['Hit Ratio','Avg. Growth','Total Recos']].values
Ytrain = df20161718['Rating'].values
Xtest = dfanalysis[['Hit Ratio','Avg. Growth','Total Recos']].values

# %%
clf = GaussianNB()
clf.fit(Xtrain, Ytrain)
GaussianNB()
Ytest = clf.predict(Xtest)

# %%
score = clf.score(Xtest,dfanalysis['Rating'].values)
score
# Out:
# 0.918918918918919

# %%
confusion_matrix(dfanalysis['Rating'],Ytest)
# Out:
# array([[13,  0,  0,  0,  0],
#        [ 0, 34,  3,  0,  0],
#        [ 0,  0, 21,  0,  0],
#        [ 0,  0,  2,  0,  0],
#        [ 0,  0,  0,  1,  0]], dtype=int64)

# %%
del dfanalysis['Rating']
dfanalysis['Rating'] = Ytest
dfanalysis
# Out:
#                          broker  Hit Ratio  Avg. Growth  Total Recos  Rating
# 0                     KRChoksey          4            3            3       3
# 1                   AUM Capital          3            2            1       2
# 2                      Religare          4            2            3       3
# 3             Enochventures.com          3            2            1       2
# 4                     Edelweiss          3            3            5       3
# ..                          ...        ...          ...          ...     ...
# 69            Ashwanigujral.com          5            4            1       3
# 70          Investec Securities          4            2            1       2
# 71         Globe Capital Market          1            1            1       1
# 72               Sushil Finance          5            3            1       3
# 73  Narnolia Financial Advisors          3            1            1       1
#
# [74 rows x 5 columns]

# %%
dfanalysis.to_sql(con=database_connection, name='finalrating', if_exists='replace')

# %%
#from sklearn.naive_bayes import MultinomialNB

# %%
#clf1 = MultinomialNB()
#clf1.fit(Xtrain, Ytrain)
#MultinomialNB()
#Ytest = clf1.predict(Xtest)

# %%
#score = clf1.score(Xtest,dfanalysis['Rating'].values)
#score
#0.5405405405405406
