# %%
import pandas as pd
import numpy as np
import glob
from glob import iglob
import os

from dateutil import parser
from datetime import datetime
from dateutil.relativedelta import relativedelta

import mysql.connector
from sqlalchemy import create_engine
import pandas.io.sql as psql
from dateutil import parser
import sqlalchemy
from datetime import datetime

# %%
path =r'C:\Users\yash\Desktop\2018\*.csv'
all_rec = iglob(path, recursive=True)   
dataframes = (pd.read_csv(f) for f in all_rec)
big_dataframe = pd.concat(dataframes, ignore_index=True)
big_dataframe
# Out:
#             SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST  \
# 0        20MICRONS     EQ     58.95     60.70     57.90     58.75     58.70
# 1       3IINFOTECH     EQ      8.40      8.80      8.30      8.80      8.80
# 2          3MINDIA     EQ  18901.00  19990.00  18901.00  19264.55  19425.00
# 3           5PAISA     EQ    383.00    383.00    357.25    357.45    357.25
# 4          63MOONS     EQ    119.55    124.40    118.00    119.40    119.20
# 5          8KMILES     EQ    908.00    921.85    900.00    901.95    904.00
# 6         A2ZINFRA     EQ     41.00     44.30     40.70     42.35     42.50
# 7       AARTIDRUGS     EQ    646.00    658.00    631.90    634.15    637.25
# 8         AARTIIND     EQ   1147.75   1149.90   1125.10   1141.00   1142.40
# 9        AARVEEDEN     EQ     50.00     51.00     48.85     50.20     50.00
# 10           AARVI     SM    102.60    110.00    102.60    107.00    107.00
# ...

# %%
del big_dataframe['OPEN']
del big_dataframe['HIGH']
del big_dataframe['LOW']
del big_dataframe['SERIES']
del big_dataframe['LAST']
del big_dataframe['PREVCLOSE']
del big_dataframe['TOTTRDQTY']
del big_dataframe['TOTTRDVAL']
del big_dataframe['TOTALTRADES']
del big_dataframe['ISIN']

# %%
big_dataframe.columns = ['Symbol','Closeval','Date']
big_dataframe
# Out:
#             Symbol  Closeval         Date
# 0        20MICRONS     58.75  01-JAN-2018
# 1       3IINFOTECH      8.80  01-JAN-2018
# 2          3MINDIA  19264.55  01-JAN-2018
# 3           5PAISA    357.45  01-JAN-2018
# 4          63MOONS    119.40  01-JAN-2018
# 5          8KMILES    901.95  01-JAN-2018
# 6         A2ZINFRA     42.35  01-JAN-2018
# 7       AARTIDRUGS    634.15  01-JAN-2018
# 8         AARTIIND   1141.00  01-JAN-2018
# 9        AARVEEDEN     50.20  01-JAN-2018
# 10           AARVI    107.00  01-JAN-2018
# 11            ABAN    201.30  01-JAN-2018
# 12             ABB   1399.65  01-JAN-2018
# 13      ABBOTINDIA   5497.75  01-JAN-2018
# 14       ABCAPITAL    186.40  01-JAN-2018
# 15           ABFRL    170.00  01-JAN-2018
# 16         ABGSHIP     13.70  01-JAN-2018
# 17       ABMINTLTD     42.05  01-JAN-2018
# 18             ACC   1731.35  01-JAN-2018
# 19         ACCELYA   1433.65  01-JAN-2018
# 20          ACCORD     57.00  01-JAN-2018
# ...

# %%
big_dataframe['Date'] = pd.to_datetime(big_dataframe['Date'], format = "%d-%b-%Y")

# %%
big_dataframe
# Out:
#             Symbol  Closeval       Date
# 0        20MICRONS     58.75 2018-01-01
# 1       3IINFOTECH      8.80 2018-01-01
# 2          3MINDIA  19264.55 2018-01-01
# 3           5PAISA    357.45 2018-01-01
# 4          63MOONS    119.40 2018-01-01
# 5          8KMILES    901.95 2018-01-01
# 6         A2ZINFRA     42.35 2018-01-01
# 7       AARTIDRUGS    634.15 2018-01-01
# 8         AARTIIND   1141.00 2018-01-01
# 9        AARVEEDEN     50.20 2018-01-01
# 10           AARVI    107.00 2018-01-01
# 11            ABAN    201.30 2018-01-01
# 12             ABB   1399.65 2018-01-01
# 13      ABBOTINDIA   5497.75 2018-01-01
# 14       ABCAPITAL    186.40 2018-01-01
# 15           ABFRL    170.00 2018-01-01
# 16         ABGSHIP     13.70 2018-01-01
# 17       ABMINTLTD     42.05 2018-01-01
# 18             ACC   1731.35 2018-01-01
# 19         ACCELYA   1433.65 2018-01-01
# 20          ACCORD     57.00 2018-01-01
# 21             ACE    141.60 2018-01-01
# ...

# %%
database_username = 'root'
database_password = 'yash'
database_ip       = '127.0.0.1'
database_name     = 'mainschema'
database_connection = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name))

# %%
df1 = big_dataframe.iloc[:50000, :]
df2 = big_dataframe.iloc[50001:100000, :]
df3 = big_dataframe.iloc[100001:150000, :]
df4 = big_dataframe.iloc[150001:200000, :]
df5 = big_dataframe.iloc[200001:250000, :]
df6 = big_dataframe.iloc[250001:300000, :]
df7 = big_dataframe.iloc[300001:350000, :]
df8 = big_dataframe.iloc[350001:400000, :]
df9 = big_dataframe.iloc[400001:450000, :]
df10 = big_dataframe.iloc[450001:, :]

# %%
df1.to_sql(con=database_connection, name='nse2018', if_exists='append')

# %%
df2.to_sql(con=database_connection, name='nse2018', if_exists='append')

# %%
df3.to_sql(con=database_connection, name='nse2018', if_exists='append')

# %%
df4.to_sql(con=database_connection, name='nse2018', if_exists='append')

# %%
df5.to_sql(con=database_connection, name='nse2018', if_exists='append')

# %%
df6.to_sql(con=database_connection, name='nse2018', if_exists='append')

# %%
df7.to_sql(con=database_connection, name='nse2018', if_exists='append')

# %%
df8.to_sql(con=database_connection, name='nse2018', if_exists='append')

# %%
df9.to_sql(con=database_connection, name='nse2018', if_exists='append')

# %%
df10.to_sql(con=database_connection, name='nse2018', if_exists='append')
